# %% [markdown]
# 운동 동작 분류 AI 경진대회에서 CNN-1D를 Keras를 활용하여 구축하여 2위를 달성하신 분의 모델을 Pytorch로 구현했습니다.
#
# https://dacon.io/competitions/official/235689/codeshare/2396?page=2&dtype=recent

# %%
import tensorflow as tf
import tensorflow.keras as keras

input_layer = keras.layers.Input((600,18))
conv1 = keras.layers.Conv1D(filters=128, kernel_size=9, padding='same')(input_layer)
conv1 = keras.layers.BatchNormalization()(conv1)
conv1 = keras.layers.Activation(activation='relu')(conv1)
conv1 = keras.layers.Dropout(rate=0.3)(conv1)

conv2 = keras.layers.Conv1D(filters=256, kernel_size=6, padding='same')(conv1)
conv2 = keras.layers.BatchNormalization()(conv2)
conv2 = keras.layers.Activation('relu')(conv2)
conv2 = keras.layers.Dropout(rate=0.4)(conv2)

conv3 = keras.layers.Conv1D(128, kernel_size=3,padding='same')(conv2)
conv3 = keras.layers.BatchNormalization()(conv3)
conv3 = keras.layers.Activation('relu')(conv3)
conv3 = keras.layers.Dropout(rate=0.5)(conv3)

gap = keras.layers.GlobalAveragePooling1D()(conv3)

output_layer = keras.layers.Dense(61, activation='softmax')(gap)

model = keras.models.Model(inputs = input_layer, outputs = output_layer)

model.summary()

model.compile(loss='categorical_crossentropy', optimizer = keras.optimizers.Adam(), 
    metrics=['accuracy'])
# Out:
# Model: "model_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_2 (InputLayer)         [(None, 600, 18)]         0
# _________________________________________________________________
# conv1d_3 (Conv1D)            (None, 600, 128)          20864
# _________________________________________________________________
# batch_normalization_3 (Batch (None, 600, 128)          512
# _________________________________________________________________
# activation_3 (Activation)    (None, 600, 128)          0
# _________________________________________________________________
# dropout_3 (Dropout)          (None, 600, 128)          0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 600, 256)          196864
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 600, 256)          1024
# _________________________________________________________________
# activation_4 (Activation)    (None, 600, 256)          0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 600, 256)          0
# _________________________________________________________________
# conv1d_5 (Conv1D)            (None, 600, 128)          98432
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 600, 128)          512
# _________________________________________________________________
# activation_5 (Activation)    (None, 600, 128)          0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 600, 128)          0
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 128)               0
# _________________________________________________________________
# dense_1 (Dense)              (None, 61)                7869
# =================================================================
# Total params: 326,077
# Trainable params: 325,053
# Non-trainable params: 1,024
# _________________________________________________________________

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F

import sys
import os
import random
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from copy import deepcopy
import matplotlib as mpl
import seaborn as sns
import warnings

from tqdm import tqdm
from numpy.fft import fft, fftshift
from scipy import signal

warnings.filterwarnings(action='ignore')
# %matplotlib inline

# %% [markdown]
# # 데이터 불러오기

# %%
paths = '/content/drive/MyDrive/DataAnalysis/운동 동작 분류 AI 경진대회/data/'

train = pd.read_csv(paths + 'train_features.csv')
train_labels = pd.read_csv(paths + 'train_labels.csv')
test = pd.read_csv(paths + 'test_features.csv')
submission = pd.read_csv(paths + 'sample_submission.csv')

# %% [markdown]
# # 재현가능성을 위한 시드 고정

# %%
# 구글 코랩을 통해서 GPU를 이용한 학습을 함

if torch.cuda.is_available():
  DEVICE = torch.device('cuda')
else:
  DEVICE = torch.device('cpu')

print(DEVICE)
# Out:
# cuda

# %%
# 재현가능성을 위한 seed 고정
def seed_everything(seed = 22):
  random.seed(seed)
  np.random.seed(seed)
  os.environ["PYTHONHASHSEED"] = str(seed)

  # torch 용
  torch.manual_seed(seed)
  torch.cuda.manual_seed(seed)
  torch.cuda.manual_seed_all(seed)
  torch.backends.cudnn.deterministic = True
  torch.backends.cudnn.benchmark = True

seed_everything()

# %% [markdown]
# # 데이터 전처리

# %%
## Energy
train['acc_Energy']=(train['acc_x']**2+train['acc_y']**2+train['acc_z']**2)**(1/3)
test['acc_Energy']=(test['acc_x']**2+test['acc_y']**2+test['acc_z']**2)**(1/3)

train['gy_Energy']=(train['gy_x']**2+train['gy_y']**2+train['gy_z']**2)**(1/3)
test['gy_Energy']=(test['gy_x']**2+test['gy_y']**2+test['gy_z']**2)**(1/3)

train['gy_acc_Energy']=((train['gy_x']-train['acc_x'])**2+(train['gy_y']-train['acc_y'])**2+(train['gy_z']-train['acc_z'])**2)**(1/3)
test['gy_acc_Energy']=((test['gy_x']-test['acc_x'])**2+(test['gy_y']-test['acc_y'])**2+(test['gy_z']-test['acc_z'])**2)**(1/3)

# %%
dt=0.02 
def jerk_signal(signal): 
  return np.array([(signal[i+1]-signal[i])/dt for i in range(len(signal)-1)])

# %%
train_dt=[]
for i in tqdm(train['id'].unique()):
    temp=train.loc[train['id']==i]
    for v in train.columns[2:]:
        values=jerk_signal(temp[v].values)
        values=np.insert(values,0,0)
        temp.loc[:,v+'_dt']=values
    train_dt.append(temp)
# Out:
# 100%|██████████| 3125/3125 [00:44<00:00, 69.75it/s]

# %%
test_dt=[]
for i in tqdm(test['id'].unique()):
    temp=test.loc[test['id']==i]
    for v in train.columns[2:]:
        values=jerk_signal(temp[v].values)
        values=np.insert(values,0,0)
        temp.loc[:,v+'_dt']=values
    test_dt.append(temp)
# Out:
# 100%|██████████| 782/782 [00:10<00:00, 76.66it/s]

# %%
from scipy import fftpack
from numpy.fft import *

def fourier_transform_one_signal(t_signal):
    complex_f_signal= fftpack.fft(t_signal)
    amplitude_f_signal=np.abs(complex_f_signal)
    return amplitude_f_signal

# %%
train=pd.concat(train_dt)

# %%
fft=[]
for i in tqdm(train['id'].unique()):
    temp=train.loc[train['id']==i]
    for i in train.columns[2:8]:
        temp[i]=fourier_transform_one_signal(temp[i].values)
    fft.append(temp)
train=pd.concat(fft)
# Out:
# 100%|██████████| 3125/3125 [00:10<00:00, 287.83it/s]

# %%
test=pd.concat(test_dt)

# %%
fft_t=[]
for i in tqdm(test['id'].unique()):
    temp=test.loc[test['id']==i]
    for i in test.columns[2:8]:
        temp[i]=fourier_transform_one_signal(temp[i].values)
    fft_t.append(temp)
test=pd.concat(fft_t)
# Out:
# 100%|██████████| 782/782 [00:01<00:00, 432.01it/s]

# %%
col=train.columns
train_s=train.copy()
test_s=test.copy()

# %%
from sklearn.preprocessing import StandardScaler,MinMaxScaler

scaler = StandardScaler()

train_s.iloc[:,2:]= scaler.fit_transform(train_s.iloc[:,2:])
train_sc = pd.DataFrame(data = train_s,columns =col)

test_s.iloc[:,2:]= scaler.transform(test_s.iloc[:,2:])
test_sc = pd.DataFrame(data = test_s,columns =col)

# %%
train_sc.head()
# Out:
#    id  time      acc_x  ...  acc_Energy_dt  gy_Energy_dt  gy_acc_Energy_dt
# 0   0     0  27.356382  ...       0.000101      0.001505          0.001501
# 1   0     1  -0.054866  ...       0.564992      0.166566          0.162871
# 2   0     2   0.024046  ...       0.175645      0.300944          0.306341
# 3   0     3   0.065632  ...      -0.077915      0.609008          0.599518
# 4   0     4   0.151477  ...       0.013483      0.259626          0.260669
#
# [5 rows x 20 columns]

# %%
X = np.swapaxes(np.array(train_sc.iloc[:,2:]).reshape(-1, 600, 18), 1, 2)

# new = []
# for i in X:
#   new.append(i.T.reshape(-1, 18, 600))
# X = np.concatenate(new)

X.shape
# Out:
# (3125, 18, 600)

# %%
test_X = np.swapaxes(np.array(test_sc.iloc[:,2:]).reshape(782, 600, -1), 1, 2)

# new = []
# for i in test_X:
#   new.append(i.T.reshape(-1, 18, 600))
# test_X = np.concatenate(new)

test_X.shape
# Out:
# (782, 18, 600)

# %%
y = train_labels['label'].values
y.shape
# Out:
# (3125,)

# %%
BATCH_SIZE = 64
EPOCHS = 100
num_classes = len(np.unique(y))

# %%
from torch.utils.data import Dataset
from torch.utils.data import DataLoader

class CustomDataset(Dataset):

  # 데이터 정의
  def __init__(self, x_data, y_data = None):
    self.x_data = x_data
    self.y_data = y_data

  # 이 데이터 셋의 총 데이터 수
  def __len__(self):
    return len(self.x_data)

  # 어떠한 idx를 받았을 때 그에 맞는 데이터를 반환
  def __getitem__(self, idx):
    if self.y_data is None:
      x = torch.FloatTensor(self.x_data[idx])
      return x
    else:
      x = torch.FloatTensor(self.x_data[idx])
      y = torch.LongTensor(self.y_data.reshape(-1,1)[idx])[0]
      return x, y

# %%
dataset = CustomDataset(x_data = X, y_data = y)

dataloader = DataLoader(
    dataset,
    batch_size = BATCH_SIZE,
    shuffle = True,
    drop_last = True
)

for (X_train, y_train) in dataloader:
  print(X_train.size())
  print(y_train.size())
  break
# Out:
# torch.Size([64, 18, 600])
# torch.Size([64])

# %% [markdown]
# # 모델 구현
#
# keras와 pytorch의 BatchNorm이 다른 이유
#
# https://stackoverflow.com/questions/60079783/difference-between-keras-batchnormalization-and-pytorchs-batchnorm2d

# %%
class CNN(nn.Module):
  def __init__(self, num_classes = 61):
    super(CNN, self).__init__()
    self.conv1 = nn.Sequential(
      nn.Conv1d(in_channels = 18, out_channels = 128, kernel_size = 9, padding= 4, stride = 1),
      nn.BatchNorm1d(128),
      nn.ReLU(),
      nn.Dropout(0.3)
    )
    
    # 커널사이즈를 비대칭으로 만들어 6과 동일한 특징을 가지게 만든다.
    self.conv2 = nn.Sequential(
      nn.Conv1d(in_channels = 128 , out_channels = 256, kernel_size = 6, padding= 0, stride = 1),
      nn.BatchNorm1d(256),
      nn.ReLU(),
      nn.Dropout(0.4)
    )

    self.conv3 = nn.Sequential(
      nn.Conv1d(in_channels = 256 , out_channels = 128, kernel_size = 3, padding= 1, stride = 1),
      nn.BatchNorm1d(128),
      nn.ReLU(),
      nn.Dropout(0.5)
    )
    self.FC = nn.Linear(128, num_classes)

  def forward(self, x):
    out = self.conv1(x)
    # 비대칭 패널 만들기
    # https://hichoe95.tistory.com/116
    p1d = (3, 2)
    out = F.pad(out, p1d, "constant", 0)
    out = self.conv2(out)
    out = self.conv3(out)
    out = F.avg_pool1d(out, 600)
    out = out.view(out.size(0), -1)
    out = self.FC(out)

    return out

# %%
from torchsummary import summary

model = CNN().to(DEVICE)
optimizer = torch.optim.Adam(model.parameters(), lr = 0.1)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = 0.5, eps = 1e-06, patience = 4)
criterion = nn.CrossEntropyLoss()

summary(CNN().to(DEVICE), (18, 600))
# Out:
# ----------------------------------------------------------------
#         Layer (type)               Output Shape         Param #
# ================================================================
#             Conv1d-1             [-1, 128, 600]          20,864
#        BatchNorm1d-2             [-1, 128, 600]             256
#               ReLU-3             [-1, 128, 600]               0
#            Dropout-4             [-1, 128, 600]               0
#             Conv1d-5             [-1, 256, 600]         196,864
#        BatchNorm1d-6             [-1, 256, 600]             512
#               ReLU-7             [-1, 256, 600]               0
#            Dropout-8             [-1, 256, 600]               0
#             Conv1d-9             [-1, 128, 600]          98,432
#       BatchNorm1d-10             [-1, 128, 600]             256
#              ReLU-11             [-1, 128, 600]               0
#           Dropout-12             [-1, 128, 600]               0
#            Linear-13                   [-1, 61]           7,869
# ================================================================
# Total params: 325,053
# Trainable params: 325,053
# Non-trainable params: 0
# ----------------------------------------------------------------
# Input size (MB): 0.04
# Forward/backward pass size (MB): 9.38
# Params size (MB): 1.24
# Estimated Total Size (MB): 10.66
# ----------------------------------------------------------------

# %% [markdown]
# # 훈련 함수

# %%
def train(model, train_loader, optimizer, log_interval):
  model.train()
  train_loss = 0
  correct = 0

  for batch_idx, (feature, label) in enumerate(train_loader):
    feature = feature.to(DEVICE)
    label = label.to(DEVICE)
    optimizer.zero_grad()
    output = model(feature)
    loss = criterion(output, label)
    loss.backward()
    optimizer.step()

    train_loss += loss.item()
    prediction = output.max(1, keepdim = True)[1]
    correct += prediction.eq(label.view_as(prediction)).sum().item()

    if batch_idx % log_interval == 0:
      print("Train Epoch: {} [{}/{} ({:.0f}%)]\tTrain Loss: {:.6f}".format(
        epoch, batch_idx * len(feature), 
        len(train_loader.dataset), 100. * batch_idx / len(train_loader), 
        loss.item()))
      
  train_loss /= len(train_loader.dataset)
  train_accuracy = 100. * correct / len(train_loader.dataset)
  return train_loss, train_accuracy

# %% [markdown]
# # 평가 함수

# %%
def evaluate(model, test_loader):
  model.eval()
  test_loss = 0
  correct = 0

  with torch.no_grad():
    for feature, label in test_loader:
      feature = feature.to(DEVICE)
      label = label.to(DEVICE)
      output = model(feature)
      test_loss += criterion(output, label).item()
      prediction = output.max(1, keepdim = True)[1]
      correct += prediction.eq(label.view_as(prediction)).sum().item()

  test_loss /= len(test_loader.dataset)
  test_accuracy = 100. * correct / len(test_loader.dataset)
  return test_loss, test_accuracy

# %% [markdown]
# # 학습

# %%
from sklearn.model_selection import StratifiedKFold
from tqdm import tqdm_notebook

# CV는 10으로
n_split = 10

# 균등하게 니눌때 사용
skf = StratifiedKFold(n_splits = n_split, shuffle=True, random_state=22)

train_oof = np.zeros_like(y)
test_oof = np.zeros((test_X.shape[0], num_classes))

test_dataset = CustomDataset(test_X)

test_dataloader = DataLoader(
    test_dataset,
    batch_size = BATCH_SIZE,
    shuffle = False)

cnt = 1

for trn_idx, val_idx in tqdm_notebook(skf.split(X, y)):
  trn_data, trn_label = X[trn_idx], y[trn_idx]
  val_data, val_label = X[val_idx], y[val_idx]

  train_dataset = CustomDataset(trn_data, trn_label)
  val_dataset = CustomDataset(val_data, val_label)
  test_dataset = CustomDataset(test)

  train_dataloader = DataLoader(
    train_dataset,
    batch_size = BATCH_SIZE,
    shuffle = True,
    drop_last = True)
  
  val_dataloader = DataLoader(
    val_dataset,
    batch_size = BATCH_SIZE,
    shuffle = False)
  
  print(f'---------------------------------{cnt}번째 oof 시작-------------------------------')

  model = CNN(num_classes = num_classes).to(DEVICE)
  optimizer = torch.optim.Adam(model.parameters(), lr = 0.1)
  scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', factor = 0.5, eps = 1e-06, patience = 4)
  criterion = nn.CrossEntropyLoss()

  best_val_accuracy = 0
  result_list = []

  for epoch in range(1, EPOCHS + 1):
    current_lrs = [x["lr"] for x in optimizer.param_groups]

    train_loss, train_accuracy = train(model, train_dataloader, optimizer, log_interval = 50)
    test_loss, test_accuracy = evaluate(model, val_dataloader)
    print(f"\n[EPOCH: {epoch}], Lr: {set(current_lrs)}\tTrain Loss: {train_loss:.4f}, \tTrain Accuracy: {train_accuracy:.2f} %, \tVal Loss: {test_loss:.4f}, \tVal Accuracy: {test_accuracy:.2f} % \n")
    scheduler.step(test_loss)

    if best_val_accuracy <= test_accuracy:

      best_info = {
      'epoch': epoch,
      'model': deepcopy(model.state_dict()),
      'train_loss': train_loss,
      'train_metric': train_accuracy,
      'val_loss': test_loss,
      'val_metric': test_accuracy,
      }

      best_val_accuracy = test_accuracy
    
    result = {
        'epoch': epoch,
        'Train Loss': train_loss,
        'Train Accuracy': train_accuracy,
        'Val Loss': test_loss,
        'Val Accuracy': test_accuracy
    }
    result_list.append(result)

  result_df = pd.DataFrame(result_list)

  # learning curve 그리기
  fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(15, 5))
  fig.suptitle('Learning Curves')
  axes[0].plot(result_df['epoch'], result_df['Train Loss'], label='Train Loss')
  axes[0].plot(result_df['epoch'], result_df['Val Loss'], label='Val Loss')
  axes[0].set_ylim(0.0, 0.05)
  axes[0].legend()

  axes[1].plot(result_df['epoch'], result_df['Train Accuracy'], label='Train Accuracy')
  axes[1].plot(result_df['epoch'], result_df['Val Accuracy'], label='Val Accuracy')
  axes[1].set_ylim(70, 100)
  axes[1].legend()
  plt.tight_layout()
  plt.show()

  print("--------------------Best Model-------------------")
  print(f"Best Val Epoch:      {best_info['epoch']}")
  print(f"Best Train Loss:     {best_info['train_loss']:.4f}")
  print(f"Best Train Accuracy: {best_info['train_metric']:.4f}")
  print(f"Best Val Loss:       {best_info['val_loss']:.4f}")
  print(f"Best Val Accuracy:   {best_info['val_metric']:.4f}")

  model.load_state_dict(best_info['model'])

  model.eval()
  test_preds = []
  val_preds = []

  with torch.no_grad():

    for inputs in test_dataloader:
      test_preds.append(F.softmax(model(inputs.cuda())).cpu().numpy())

    for inputs, targets in val_dataloader:
      val_preds.append(model(inputs.cuda()).cpu().numpy().argmax(axis=1))

  train_oof[val_idx] = np.concatenate(val_preds)
  test_oof += np.concatenate(test_preds) / n_split

  print(f'---------------------------------{cnt}번째 oof 종료-------------------------------')
  cnt += 1
# Out:
# HBox(children=(FloatProgress(value=1.0, bar_style='info', max=1.0), HTML(value='')))
# ---------------------------------1번째 oof 시작-------------------------------
# Train Epoch: 1 [0/2812 (0%)]	Train Loss: 4.146671
#
# [EPOCH: 1], Lr: {0.1}	Train Loss: 0.0432, 	Train Accuracy: 47.83 %, 	Val Loss: 0.0373, 	Val Accuracy: 52.08 %
#
# Train Epoch: 2 [0/2812 (0%)]	Train Loss: 2.054962
#
# [EPOCH: 2], Lr: {0.1}	Train Loss: 0.0317, 	Train Accuracy: 52.42 %, 	Val Loss: 0.0327, 	Val Accuracy: 53.67 %
#
# Train Epoch: 3 [0/2812 (0%)]	Train Loss: 1.518603
#
# [EPOCH: 3], Lr: {0.1}	Train Loss: 0.0273, 	Train Accuracy: 54.94 %, 	Val Loss: 0.0311, 	Val Accuracy: 56.23 %
#
# Train Epoch: 4 [0/2812 (0%)]	Train Loss: 1.598723
#
# [EPOCH: 4], Lr: {0.1}	Train Loss: 0.0248, 	Train Accuracy: 56.29 %, 	Val Loss: 0.0231, 	Val Accuracy: 62.62 %
#
# Train Epoch: 5 [0/2812 (0%)]	Train Loss: 1.668726
#
# [EPOCH: 5], Lr: {0.1}	Train Loss: 0.0221, 	Train Accuracy: 59.71 %, 	Val Loss: 0.0225, 	Val Accuracy: 59.42 %
#
# Train Epoch: 6 [0/2812 (0%)]	Train Loss: 1.413494
#
# [EPOCH: 6], Lr: {0.1}	Train Loss: 0.0204, 	Train Accuracy: 61.49 %, 	Val Loss: 0.0204, 	Val Accuracy: 63.58 %
#
# Train Epoch: 7 [0/2812 (0%)]	Train Loss: 1.053488
#
# [EPOCH: 7], Lr: {0.1}	Train Loss: 0.0196, 	Train Accuracy: 63.05 %, 	Val Loss: 0.0202, 	Val Accuracy: 62.94 %
#
# Train Epoch: 8 [0/2812 (0%)]	Train Loss: 1.223546
#
# [EPOCH: 8], Lr: {0.1}	Train Loss: 0.0175, 	Train Accuracy: 66.61 %, 	Val Loss: 0.0199, 	Val Accuracy: 67.09 %
#
# Train Epoch: 9 [0/2812 (0%)]	Train Loss: 1.393092
#
# [EPOCH: 9], Lr: {0.1}	Train Loss: 0.0161, 	Train Accuracy: 67.21 %, 	Val Loss: 0.0174, 	Val Accuracy: 69.97 %
#
# Train Epoch: 10 [0/2812 (0%)]	Train Loss: 1.012379
#
# [EPOCH: 10], Lr: {0.1}	Train Loss: 0.0146, 	Train Accuracy: 70.45 %, 	Val Loss: 0.0170, 	Val Accuracy: 69.01 %
#
# Train Epoch: 11 [0/2812 (0%)]	Train Loss: 1.167302
#
# [EPOCH: 11], Lr: {0.1}	Train Loss: 0.0145, 	Train Accuracy: 70.34 %, 	Val Loss: 0.0150, 	Val Accuracy: 74.12 %
#
# Train Epoch: 12 [0/2812 (0%)]	Train Loss: 0.962203
#
# [EPOCH: 12], Lr: {0.1}	Train Loss: 0.0126, 	Train Accuracy: 73.68 %, 	Val Loss: 0.0167, 	Val Accuracy: 70.29 %
#
# Train Epoch: 13 [0/2812 (0%)]	Train Loss: 0.741337
#
# [EPOCH: 13], Lr: {0.1}	Train Loss: 0.0130, 	Train Accuracy: 72.62 %, 	Val Loss: 0.0161, 	Val Accuracy: 69.97 %
#
# Train Epoch: 14 [0/2812 (0%)]	Train Loss: 0.679451
#
# [EPOCH: 14], Lr: {0.1}	Train Loss: 0.0123, 	Train Accuracy: 73.90 %, 	Val Loss: 0.0151, 	Val Accuracy: 74.12 %
#
# Train Epoch: 15 [0/2812 (0%)]	Train Loss: 0.801477
#
# [EPOCH: 15], Lr: {0.1}	Train Loss: 0.0116, 	Train Accuracy: 75.07 %, 	Val Loss: 0.0177, 	Val Accuracy: 69.97 %
#
# Train Epoch: 16 [0/2812 (0%)]	Train Loss: 0.619710
#
# [EPOCH: 16], Lr: {0.1}	Train Loss: 0.0113, 	Train Accuracy: 75.39 %, 	Val Loss: 0.0166, 	Val Accuracy: 73.16 %
#
# Train Epoch: 17 [0/2812 (0%)]	Train Loss: 0.531455
#
# [EPOCH: 17], Lr: {0.05}	Train Loss: 0.0092, 	Train Accuracy: 78.59 %, 	Val Loss: 0.0132, 	Val Accuracy: 77.00 %
#
# Train Epoch: 18 [0/2812 (0%)]	Train Loss: 0.469453
#
# [EPOCH: 18], Lr: {0.05}	Train Loss: 0.0085, 	Train Accuracy: 80.58 %, 	Val Loss: 0.0131, 	Val Accuracy: 77.00 %
#
# Train Epoch: 19 [0/2812 (0%)]	Train Loss: 0.427166
#
# [EPOCH: 19], Lr: {0.05}	Train Loss: 0.0083, 	Train Accuracy: 81.08 %, 	Val Loss: 0.0141, 	Val Accuracy: 75.72 %
#
# Train Epoch: 20 [0/2812 (0%)]	Train Loss: 0.560837
#
# [EPOCH: 20], Lr: {0.05}	Train Loss: 0.0083, 	Train Accuracy: 80.65 %, 	Val Loss: 0.0133, 	Val Accuracy: 78.91 %
#
# Train Epoch: 21 [0/2812 (0%)]	Train Loss: 0.604267
#
# [EPOCH: 21], Lr: {0.05}	Train Loss: 0.0079, 	Train Accuracy: 81.44 %, 	Val Loss: 0.0116, 	Val Accuracy: 79.87 %
#
# Train Epoch: 22 [0/2812 (0%)]	Train Loss: 0.444084
#
# [EPOCH: 22], Lr: {0.05}	Train Loss: 0.0079, 	Train Accuracy: 81.01 %, 	Val Loss: 0.0127, 	Val Accuracy: 77.96 %
#
# Train Epoch: 23 [0/2812 (0%)]	Train Loss: 0.522377
#
# [EPOCH: 23], Lr: {0.05}	Train Loss: 0.0073, 	Train Accuracy: 82.50 %, 	Val Loss: 0.0128, 	Val Accuracy: 77.96 %
#
# Train Epoch: 24 [0/2812 (0%)]	Train Loss: 0.643737
#
# [EPOCH: 24], Lr: {0.05}	Train Loss: 0.0072, 	Train Accuracy: 83.21 %, 	Val Loss: 0.0115, 	Val Accuracy: 80.19 %
#
# Train Epoch: 25 [0/2812 (0%)]	Train Loss: 0.656463
#
# [EPOCH: 25], Lr: {0.05}	Train Loss: 0.0075, 	Train Accuracy: 81.76 %, 	Val Loss: 0.0122, 	Val Accuracy: 78.91 %
#
# Train Epoch: 26 [0/2812 (0%)]	Train Loss: 0.457977
#
# [EPOCH: 26], Lr: {0.05}	Train Loss: 0.0069, 	Train Accuracy: 83.18 %, 	Val Loss: 0.0127, 	Val Accuracy: 78.59 %
#
# Train Epoch: 27 [0/2812 (0%)]	Train Loss: 0.364642
#
# [EPOCH: 27], Lr: {0.05}	Train Loss: 0.0069, 	Train Accuracy: 83.07 %, 	Val Loss: 0.0119, 	Val Accuracy: 80.51 %
#
# Train Epoch: 28 [0/2812 (0%)]	Train Loss: 0.324372
#
# [EPOCH: 28], Lr: {0.05}	Train Loss: 0.0066, 	Train Accuracy: 84.35 %, 	Val Loss: 0.0134, 	Val Accuracy: 80.19 %
#
# Train Epoch: 29 [0/2812 (0%)]	Train Loss: 0.415597
#
# [EPOCH: 29], Lr: {0.05}	Train Loss: 0.0070, 	Train Accuracy: 82.72 %, 	Val Loss: 0.0119, 	Val Accuracy: 78.91 %
#
# Train Epoch: 30 [0/2812 (0%)]	Train Loss: 0.312847
#
# [EPOCH: 30], Lr: {0.025}	Train Loss: 0.0057, 	Train Accuracy: 86.06 %, 	Val Loss: 0.0111, 	Val Accuracy: 79.87 %
#
# Train Epoch: 31 [0/2812 (0%)]	Train Loss: 0.325296
#
# [EPOCH: 31], Lr: {0.025}	Train Loss: 0.0054, 	Train Accuracy: 86.38 %, 	Val Loss: 0.0110, 	Val Accuracy: 82.11 %
#
# Train Epoch: 32 [0/2812 (0%)]	Train Loss: 0.361131
#
# [EPOCH: 32], Lr: {0.025}	Train Loss: 0.0054, 	Train Accuracy: 87.59 %, 	Val Loss: 0.0099, 	Val Accuracy: 80.83 %
#
# Train Epoch: 33 [0/2812 (0%)]	Train Loss: 0.322029
#
# [EPOCH: 33], Lr: {0.025}	Train Loss: 0.0051, 	Train Accuracy: 87.62 %, 	Val Loss: 0.0111, 	Val Accuracy: 82.11 %
#
# Train Epoch: 34 [0/2812 (0%)]	Train Loss: 0.377757
#
# [EPOCH: 34], Lr: {0.025}	Train Loss: 0.0051, 	Train Accuracy: 86.38 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.43 %
#
# Train Epoch: 35 [0/2812 (0%)]	Train Loss: 0.466679
#
# [EPOCH: 35], Lr: {0.025}	Train Loss: 0.0049, 	Train Accuracy: 87.77 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.75 %
#
# Train Epoch: 36 [0/2812 (0%)]	Train Loss: 0.112056
#
# [EPOCH: 36], Lr: {0.025}	Train Loss: 0.0049, 	Train Accuracy: 87.94 %, 	Val Loss: 0.0108, 	Val Accuracy: 81.79 %
#
# Train Epoch: 37 [0/2812 (0%)]	Train Loss: 0.289943
#
# [EPOCH: 37], Lr: {0.025}	Train Loss: 0.0048, 	Train Accuracy: 88.16 %, 	Val Loss: 0.0118, 	Val Accuracy: 82.75 %
#
# Train Epoch: 38 [0/2812 (0%)]	Train Loss: 0.334423
#
# [EPOCH: 38], Lr: {0.0125}	Train Loss: 0.0042, 	Train Accuracy: 89.33 %, 	Val Loss: 0.0105, 	Val Accuracy: 83.39 %
#
# Train Epoch: 39 [0/2812 (0%)]	Train Loss: 0.250457
#
# [EPOCH: 39], Lr: {0.0125}	Train Loss: 0.0041, 	Train Accuracy: 89.69 %, 	Val Loss: 0.0110, 	Val Accuracy: 83.39 %
#
# Train Epoch: 40 [0/2812 (0%)]	Train Loss: 0.312247
#
# [EPOCH: 40], Lr: {0.0125}	Train Loss: 0.0041, 	Train Accuracy: 89.30 %, 	Val Loss: 0.0103, 	Val Accuracy: 82.75 %
#
# Train Epoch: 41 [0/2812 (0%)]	Train Loss: 0.260062
#
# [EPOCH: 41], Lr: {0.0125}	Train Loss: 0.0041, 	Train Accuracy: 89.54 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.75 %
#
# Train Epoch: 42 [0/2812 (0%)]	Train Loss: 0.418463
#
# [EPOCH: 42], Lr: {0.0125}	Train Loss: 0.0040, 	Train Accuracy: 89.30 %, 	Val Loss: 0.0112, 	Val Accuracy: 82.11 %
#
# Train Epoch: 43 [0/2812 (0%)]	Train Loss: 0.158072
#
# [EPOCH: 43], Lr: {0.00625}	Train Loss: 0.0038, 	Train Accuracy: 89.94 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.75 %
#
# Train Epoch: 44 [0/2812 (0%)]	Train Loss: 0.195156
#
# [EPOCH: 44], Lr: {0.00625}	Train Loss: 0.0038, 	Train Accuracy: 90.04 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 45 [0/2812 (0%)]	Train Loss: 0.283512
#
# [EPOCH: 45], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.36 %, 	Val Loss: 0.0105, 	Val Accuracy: 83.07 %
#
# Train Epoch: 46 [0/2812 (0%)]	Train Loss: 0.209697
#
# [EPOCH: 46], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.07 %
#
# Train Epoch: 47 [0/2812 (0%)]	Train Loss: 0.251633
#
# [EPOCH: 47], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.75 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.35 %
#
# Train Epoch: 48 [0/2812 (0%)]	Train Loss: 0.201560
#
# [EPOCH: 48], Lr: {0.003125}	Train Loss: 0.0034, 	Train Accuracy: 90.90 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.35 %
#
# Train Epoch: 49 [0/2812 (0%)]	Train Loss: 0.204382
#
# [EPOCH: 49], Lr: {0.003125}	Train Loss: 0.0035, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0105, 	Val Accuracy: 84.03 %
#
# Train Epoch: 50 [0/2812 (0%)]	Train Loss: 0.063616
#
# [EPOCH: 50], Lr: {0.003125}	Train Loss: 0.0036, 	Train Accuracy: 90.50 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.07 %
#
# Train Epoch: 51 [0/2812 (0%)]	Train Loss: 0.236577
#
# [EPOCH: 51], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.07 %
#
# Train Epoch: 52 [0/2812 (0%)]	Train Loss: 0.264828
#
# [EPOCH: 52], Lr: {0.003125}	Train Loss: 0.0034, 	Train Accuracy: 90.83 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.71 %
#
# Train Epoch: 53 [0/2812 (0%)]	Train Loss: 0.165801
#
# [EPOCH: 53], Lr: {0.0015625}	Train Loss: 0.0035, 	Train Accuracy: 90.61 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.39 %
#
# Train Epoch: 54 [0/2812 (0%)]	Train Loss: 0.184390
#
# [EPOCH: 54], Lr: {0.0015625}	Train Loss: 0.0034, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 55 [0/2812 (0%)]	Train Loss: 0.408858
#
# [EPOCH: 55], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.75 %
#
# Train Epoch: 56 [0/2812 (0%)]	Train Loss: 0.208144
#
# [EPOCH: 56], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 91.39 %, 	Val Loss: 0.0105, 	Val Accuracy: 84.66 %
#
# Train Epoch: 57 [0/2812 (0%)]	Train Loss: 0.135692
#
# [EPOCH: 57], Lr: {0.0015625}	Train Loss: 0.0033, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.98 %
#
# Train Epoch: 58 [0/2812 (0%)]	Train Loss: 0.231137
#
# [EPOCH: 58], Lr: {0.00078125}	Train Loss: 0.0034, 	Train Accuracy: 90.72 %, 	Val Loss: 0.0105, 	Val Accuracy: 84.66 %
#
# Train Epoch: 59 [0/2812 (0%)]	Train Loss: 0.151018
#
# [EPOCH: 59], Lr: {0.00078125}	Train Loss: 0.0031, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0105, 	Val Accuracy: 84.35 %
#
# Train Epoch: 60 [0/2812 (0%)]	Train Loss: 0.240013
#
# [EPOCH: 60], Lr: {0.00078125}	Train Loss: 0.0033, 	Train Accuracy: 91.29 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.71 %
#
# Train Epoch: 61 [0/2812 (0%)]	Train Loss: 0.201572
#
# [EPOCH: 61], Lr: {0.00078125}	Train Loss: 0.0034, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0105, 	Val Accuracy: 84.66 %
#
# Train Epoch: 62 [0/2812 (0%)]	Train Loss: 0.164230
#
# [EPOCH: 62], Lr: {0.00078125}	Train Loss: 0.0032, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 63 [0/2812 (0%)]	Train Loss: 0.148503
#
# [EPOCH: 63], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.39 %
#
# Train Epoch: 64 [0/2812 (0%)]	Train Loss: 0.103917
#
# [EPOCH: 64], Lr: {0.000390625}	Train Loss: 0.0033, 	Train Accuracy: 91.54 %, 	Val Loss: 0.0107, 	Val Accuracy: 84.03 %
#
# Train Epoch: 65 [0/2812 (0%)]	Train Loss: 0.224037
#
# [EPOCH: 65], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0107, 	Val Accuracy: 84.35 %
#
# Train Epoch: 66 [0/2812 (0%)]	Train Loss: 0.350857
#
# [EPOCH: 66], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 92.07 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.39 %
#
# Train Epoch: 67 [0/2812 (0%)]	Train Loss: 0.133593
#
# [EPOCH: 67], Lr: {0.000390625}	Train Loss: 0.0031, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 68 [0/2812 (0%)]	Train Loss: 0.371461
#
# [EPOCH: 68], Lr: {0.0001953125}	Train Loss: 0.0033, 	Train Accuracy: 91.39 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.71 %
#
# Train Epoch: 69 [0/2812 (0%)]	Train Loss: 0.203861
#
# [EPOCH: 69], Lr: {0.0001953125}	Train Loss: 0.0033, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0108, 	Val Accuracy: 84.35 %
#
# Train Epoch: 70 [0/2812 (0%)]	Train Loss: 0.131363
#
# [EPOCH: 70], Lr: {0.0001953125}	Train Loss: 0.0033, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 71 [0/2812 (0%)]	Train Loss: 0.134187
#
# [EPOCH: 71], Lr: {0.0001953125}	Train Loss: 0.0030, 	Train Accuracy: 92.28 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.71 %
#
# Train Epoch: 72 [0/2812 (0%)]	Train Loss: 0.279522
#
# [EPOCH: 72], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.39 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.71 %
#
# Train Epoch: 73 [0/2812 (0%)]	Train Loss: 0.163473
#
# [EPOCH: 73], Lr: {9.765625e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 74 [0/2812 (0%)]	Train Loss: 0.386644
#
# [EPOCH: 74], Lr: {9.765625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0108, 	Val Accuracy: 84.03 %
#
# Train Epoch: 75 [0/2812 (0%)]	Train Loss: 0.300610
#
# [EPOCH: 75], Lr: {9.765625e-05}	Train Loss: 0.0033, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 76 [0/2812 (0%)]	Train Loss: 0.295472
#
# [EPOCH: 76], Lr: {9.765625e-05}	Train Loss: 0.0033, 	Train Accuracy: 90.86 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.75 %
#
# Train Epoch: 77 [0/2812 (0%)]	Train Loss: 0.213283
#
# [EPOCH: 77], Lr: {9.765625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.54 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.07 %
#
# Train Epoch: 78 [0/2812 (0%)]	Train Loss: 0.187681
#
# [EPOCH: 78], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.71 %, 	Val Loss: 0.0107, 	Val Accuracy: 84.03 %
#
# Train Epoch: 79 [0/2812 (0%)]	Train Loss: 0.134968
#
# [EPOCH: 79], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.71 %
#
# Train Epoch: 80 [0/2812 (0%)]	Train Loss: 0.199786
#
# [EPOCH: 80], Lr: {4.8828125e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 81 [0/2812 (0%)]	Train Loss: 0.204383
#
# [EPOCH: 81], Lr: {4.8828125e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.00 %, 	Val Loss: 0.0107, 	Val Accuracy: 84.35 %
#
# Train Epoch: 82 [0/2812 (0%)]	Train Loss: 0.163761
#
# [EPOCH: 82], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.54 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.07 %
#
# Train Epoch: 83 [0/2812 (0%)]	Train Loss: 0.283426
#
# [EPOCH: 83], Lr: {2.44140625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 84 [0/2812 (0%)]	Train Loss: 0.118050
#
# [EPOCH: 84], Lr: {2.44140625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.50 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 85 [0/2812 (0%)]	Train Loss: 0.184093
#
# [EPOCH: 85], Lr: {2.44140625e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.07 %
#
# Train Epoch: 86 [0/2812 (0%)]	Train Loss: 0.176426
#
# [EPOCH: 86], Lr: {2.44140625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.71 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 87 [0/2812 (0%)]	Train Loss: 0.247531
#
# [EPOCH: 87], Lr: {2.44140625e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.07 %
#
# Train Epoch: 88 [0/2812 (0%)]	Train Loss: 0.146564
#
# [EPOCH: 88], Lr: {1.220703125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.82 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.07 %
#
# Train Epoch: 89 [0/2812 (0%)]	Train Loss: 0.259472
#
# [EPOCH: 89], Lr: {1.220703125e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.39 %
#
# Train Epoch: 90 [0/2812 (0%)]	Train Loss: 0.167680
#
# [EPOCH: 90], Lr: {1.220703125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.75 %
#
# Train Epoch: 91 [0/2812 (0%)]	Train Loss: 0.271277
#
# [EPOCH: 91], Lr: {1.220703125e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.61 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.71 %
#
# Train Epoch: 92 [0/2812 (0%)]	Train Loss: 0.234781
#
# [EPOCH: 92], Lr: {1.220703125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.75 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 93 [0/2812 (0%)]	Train Loss: 0.173633
#
# [EPOCH: 93], Lr: {6.103515625e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.75 %
#
# Train Epoch: 94 [0/2812 (0%)]	Train Loss: 0.183330
#
# [EPOCH: 94], Lr: {6.103515625e-06}	Train Loss: 0.0032, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 95 [0/2812 (0%)]	Train Loss: 0.219568
#
# [EPOCH: 95], Lr: {6.103515625e-06}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.39 %
#
# Train Epoch: 96 [0/2812 (0%)]	Train Loss: 0.399814
#
# [EPOCH: 96], Lr: {6.103515625e-06}	Train Loss: 0.0033, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0106, 	Val Accuracy: 84.03 %
#
# Train Epoch: 97 [0/2812 (0%)]	Train Loss: 0.257313
#
# [EPOCH: 97], Lr: {6.103515625e-06}	Train Loss: 0.0033, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.71 %
#
# Train Epoch: 98 [0/2812 (0%)]	Train Loss: 0.236517
#
# [EPOCH: 98], Lr: {3.0517578125e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.15 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.71 %
#
# Train Epoch: 99 [0/2812 (0%)]	Train Loss: 0.231853
#
# [EPOCH: 99], Lr: {3.0517578125e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.71 %
#
# Train Epoch: 100 [0/2812 (0%)]	Train Loss: 0.225539
#
# [EPOCH: 100], Lr: {3.0517578125e-06}	Train Loss: 0.0033, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0107, 	Val Accuracy: 84.03 %
# --------------------Best Model-------------------
# Best Val Epoch:      57
# Best Train Loss:     0.0033
# Best Train Accuracy: 91.3229
# Best Val Loss:       0.0106
# Best Val Accuracy:   84.9840
# ---------------------------------1번째 oof 종료-------------------------------
# ---------------------------------2번째 oof 시작-------------------------------
# Train Epoch: 1 [0/2812 (0%)]	Train Loss: 4.160616
#
# [EPOCH: 1], Lr: {0.1}	Train Loss: 0.0416, 	Train Accuracy: 47.33 %, 	Val Loss: 0.0352, 	Val Accuracy: 53.35 %
#
# Train Epoch: 2 [0/2812 (0%)]	Train Loss: 2.059135
#
# [EPOCH: 2], Lr: {0.1}	Train Loss: 0.0304, 	Train Accuracy: 51.60 %, 	Val Loss: 0.0282, 	Val Accuracy: 55.91 %
#
# Train Epoch: 3 [0/2812 (0%)]	Train Loss: 1.607596
#
# [EPOCH: 3], Lr: {0.1}	Train Loss: 0.0262, 	Train Accuracy: 54.16 %, 	Val Loss: 0.0274, 	Val Accuracy: 58.79 %
#
# Train Epoch: 4 [0/2812 (0%)]	Train Loss: 1.819880
#
# [EPOCH: 4], Lr: {0.1}	Train Loss: 0.0227, 	Train Accuracy: 57.29 %, 	Val Loss: 0.0211, 	Val Accuracy: 63.26 %
#
# Train Epoch: 5 [0/2812 (0%)]	Train Loss: 1.413224
#
# [EPOCH: 5], Lr: {0.1}	Train Loss: 0.0194, 	Train Accuracy: 62.70 %, 	Val Loss: 0.0231, 	Val Accuracy: 62.30 %
#
# Train Epoch: 6 [0/2812 (0%)]	Train Loss: 1.368069
#
# [EPOCH: 6], Lr: {0.1}	Train Loss: 0.0172, 	Train Accuracy: 66.47 %, 	Val Loss: 0.0180, 	Val Accuracy: 69.97 %
#
# Train Epoch: 7 [0/2812 (0%)]	Train Loss: 0.966183
#
# [EPOCH: 7], Lr: {0.1}	Train Loss: 0.0157, 	Train Accuracy: 68.31 %, 	Val Loss: 0.0169, 	Val Accuracy: 70.93 %
#
# Train Epoch: 8 [0/2812 (0%)]	Train Loss: 1.063121
#
# [EPOCH: 8], Lr: {0.1}	Train Loss: 0.0151, 	Train Accuracy: 68.39 %, 	Val Loss: 0.0170, 	Val Accuracy: 69.01 %
#
# Train Epoch: 9 [0/2812 (0%)]	Train Loss: 0.706628
#
# [EPOCH: 9], Lr: {0.1}	Train Loss: 0.0139, 	Train Accuracy: 71.34 %, 	Val Loss: 0.0163, 	Val Accuracy: 71.88 %
#
# Train Epoch: 10 [0/2812 (0%)]	Train Loss: 0.660646
#
# [EPOCH: 10], Lr: {0.1}	Train Loss: 0.0138, 	Train Accuracy: 70.80 %, 	Val Loss: 0.0176, 	Val Accuracy: 70.93 %
#
# Train Epoch: 11 [0/2812 (0%)]	Train Loss: 0.684213
#
# [EPOCH: 11], Lr: {0.1}	Train Loss: 0.0128, 	Train Accuracy: 73.01 %, 	Val Loss: 0.0195, 	Val Accuracy: 68.69 %
#
# Train Epoch: 12 [0/2812 (0%)]	Train Loss: 0.910606
#
# [EPOCH: 12], Lr: {0.1}	Train Loss: 0.0128, 	Train Accuracy: 72.26 %, 	Val Loss: 0.0164, 	Val Accuracy: 74.76 %
#
# Train Epoch: 13 [0/2812 (0%)]	Train Loss: 0.647339
#
# [EPOCH: 13], Lr: {0.1}	Train Loss: 0.0114, 	Train Accuracy: 73.72 %, 	Val Loss: 0.0150, 	Val Accuracy: 76.36 %
#
# Train Epoch: 14 [0/2812 (0%)]	Train Loss: 0.496190
#
# [EPOCH: 14], Lr: {0.1}	Train Loss: 0.0108, 	Train Accuracy: 76.39 %, 	Val Loss: 0.0143, 	Val Accuracy: 75.72 %
#
# Train Epoch: 15 [0/2812 (0%)]	Train Loss: 0.429683
#
# [EPOCH: 15], Lr: {0.1}	Train Loss: 0.0104, 	Train Accuracy: 77.20 %, 	Val Loss: 0.0143, 	Val Accuracy: 75.08 %
#
# Train Epoch: 16 [0/2812 (0%)]	Train Loss: 0.504047
#
# [EPOCH: 16], Lr: {0.1}	Train Loss: 0.0101, 	Train Accuracy: 77.24 %, 	Val Loss: 0.0145, 	Val Accuracy: 76.68 %
#
# Train Epoch: 17 [0/2812 (0%)]	Train Loss: 1.100936
#
# [EPOCH: 17], Lr: {0.1}	Train Loss: 0.0101, 	Train Accuracy: 76.85 %, 	Val Loss: 0.0210, 	Val Accuracy: 68.37 %
#
# Train Epoch: 18 [0/2812 (0%)]	Train Loss: 0.833377
#
# [EPOCH: 18], Lr: {0.1}	Train Loss: 0.0094, 	Train Accuracy: 78.41 %, 	Val Loss: 0.0152, 	Val Accuracy: 73.48 %
#
# Train Epoch: 19 [0/2812 (0%)]	Train Loss: 0.476412
#
# [EPOCH: 19], Lr: {0.1}	Train Loss: 0.0093, 	Train Accuracy: 78.73 %, 	Val Loss: 0.0167, 	Val Accuracy: 72.52 %
#
# Train Epoch: 20 [0/2812 (0%)]	Train Loss: 0.537451
#
# [EPOCH: 20], Lr: {0.05}	Train Loss: 0.0079, 	Train Accuracy: 80.41 %, 	Val Loss: 0.0132, 	Val Accuracy: 78.27 %
#
# Train Epoch: 21 [0/2812 (0%)]	Train Loss: 0.484594
#
# [EPOCH: 21], Lr: {0.05}	Train Loss: 0.0070, 	Train Accuracy: 82.47 %, 	Val Loss: 0.0115, 	Val Accuracy: 81.15 %
#
# Train Epoch: 22 [0/2812 (0%)]	Train Loss: 0.344039
#
# [EPOCH: 22], Lr: {0.05}	Train Loss: 0.0066, 	Train Accuracy: 83.75 %, 	Val Loss: 0.0127, 	Val Accuracy: 80.51 %
#
# Train Epoch: 23 [0/2812 (0%)]	Train Loss: 0.465167
#
# [EPOCH: 23], Lr: {0.05}	Train Loss: 0.0064, 	Train Accuracy: 83.82 %, 	Val Loss: 0.0126, 	Val Accuracy: 78.91 %
#
# Train Epoch: 24 [0/2812 (0%)]	Train Loss: 0.399613
#
# [EPOCH: 24], Lr: {0.05}	Train Loss: 0.0061, 	Train Accuracy: 84.46 %, 	Val Loss: 0.0124, 	Val Accuracy: 80.51 %
#
# Train Epoch: 25 [0/2812 (0%)]	Train Loss: 0.541930
#
# [EPOCH: 25], Lr: {0.05}	Train Loss: 0.0059, 	Train Accuracy: 84.89 %, 	Val Loss: 0.0126, 	Val Accuracy: 79.87 %
#
# Train Epoch: 26 [0/2812 (0%)]	Train Loss: 0.210862
#
# [EPOCH: 26], Lr: {0.05}	Train Loss: 0.0063, 	Train Accuracy: 84.85 %, 	Val Loss: 0.0124, 	Val Accuracy: 80.51 %
#
# Train Epoch: 27 [0/2812 (0%)]	Train Loss: 0.233793
#
# [EPOCH: 27], Lr: {0.025}	Train Loss: 0.0056, 	Train Accuracy: 85.81 %, 	Val Loss: 0.0115, 	Val Accuracy: 81.15 %
#
# Train Epoch: 28 [0/2812 (0%)]	Train Loss: 0.284709
#
# [EPOCH: 28], Lr: {0.025}	Train Loss: 0.0052, 	Train Accuracy: 86.81 %, 	Val Loss: 0.0113, 	Val Accuracy: 82.11 %
#
# Train Epoch: 29 [0/2812 (0%)]	Train Loss: 0.217170
#
# [EPOCH: 29], Lr: {0.025}	Train Loss: 0.0049, 	Train Accuracy: 87.06 %, 	Val Loss: 0.0112, 	Val Accuracy: 80.51 %
#
# Train Epoch: 30 [0/2812 (0%)]	Train Loss: 0.230354
#
# [EPOCH: 30], Lr: {0.025}	Train Loss: 0.0048, 	Train Accuracy: 87.48 %, 	Val Loss: 0.0122, 	Val Accuracy: 80.51 %
#
# Train Epoch: 31 [0/2812 (0%)]	Train Loss: 0.367925
#
# [EPOCH: 31], Lr: {0.025}	Train Loss: 0.0049, 	Train Accuracy: 87.34 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.39 %
#
# Train Epoch: 32 [0/2812 (0%)]	Train Loss: 0.521880
#
# [EPOCH: 32], Lr: {0.025}	Train Loss: 0.0046, 	Train Accuracy: 87.52 %, 	Val Loss: 0.0123, 	Val Accuracy: 81.47 %
#
# Train Epoch: 33 [0/2812 (0%)]	Train Loss: 0.223650
#
# [EPOCH: 33], Lr: {0.025}	Train Loss: 0.0046, 	Train Accuracy: 87.66 %, 	Val Loss: 0.0121, 	Val Accuracy: 81.47 %
#
# Train Epoch: 34 [0/2812 (0%)]	Train Loss: 0.110005
#
# [EPOCH: 34], Lr: {0.025}	Train Loss: 0.0050, 	Train Accuracy: 86.74 %, 	Val Loss: 0.0118, 	Val Accuracy: 80.83 %
#
# Train Epoch: 35 [0/2812 (0%)]	Train Loss: 0.387547
#
# [EPOCH: 35], Lr: {0.0125}	Train Loss: 0.0043, 	Train Accuracy: 88.19 %, 	Val Loss: 0.0115, 	Val Accuracy: 82.11 %
#
# Train Epoch: 36 [0/2812 (0%)]	Train Loss: 0.253259
#
# [EPOCH: 36], Lr: {0.0125}	Train Loss: 0.0040, 	Train Accuracy: 88.98 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.07 %
#
# Train Epoch: 37 [0/2812 (0%)]	Train Loss: 0.196107
#
# [EPOCH: 37], Lr: {0.0125}	Train Loss: 0.0038, 	Train Accuracy: 89.76 %, 	Val Loss: 0.0113, 	Val Accuracy: 83.39 %
#
# Train Epoch: 38 [0/2812 (0%)]	Train Loss: 0.208265
#
# [EPOCH: 38], Lr: {0.0125}	Train Loss: 0.0039, 	Train Accuracy: 89.44 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.71 %
#
# Train Epoch: 39 [0/2812 (0%)]	Train Loss: 0.212768
#
# [EPOCH: 39], Lr: {0.0125}	Train Loss: 0.0039, 	Train Accuracy: 88.98 %, 	Val Loss: 0.0117, 	Val Accuracy: 82.43 %
#
# Train Epoch: 40 [0/2812 (0%)]	Train Loss: 0.149845
#
# [EPOCH: 40], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.61 %, 	Val Loss: 0.0118, 	Val Accuracy: 82.43 %
#
# Train Epoch: 41 [0/2812 (0%)]	Train Loss: 0.396577
#
# [EPOCH: 41], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.50 %, 	Val Loss: 0.0121, 	Val Accuracy: 81.15 %
#
# Train Epoch: 42 [0/2812 (0%)]	Train Loss: 0.131236
#
# [EPOCH: 42], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 90.83 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.11 %
#
# Train Epoch: 43 [0/2812 (0%)]	Train Loss: 0.315391
#
# [EPOCH: 43], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 89.76 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.07 %
#
# Train Epoch: 44 [0/2812 (0%)]	Train Loss: 0.277743
#
# [EPOCH: 44], Lr: {0.00625}	Train Loss: 0.0034, 	Train Accuracy: 90.50 %, 	Val Loss: 0.0119, 	Val Accuracy: 80.83 %
#
# Train Epoch: 45 [0/2812 (0%)]	Train Loss: 0.201487
#
# [EPOCH: 45], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 90.79 %, 	Val Loss: 0.0120, 	Val Accuracy: 81.47 %
#
# Train Epoch: 46 [0/2812 (0%)]	Train Loss: 0.136377
#
# [EPOCH: 46], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 90.61 %, 	Val Loss: 0.0122, 	Val Accuracy: 83.71 %
#
# Train Epoch: 47 [0/2812 (0%)]	Train Loss: 0.301265
#
# [EPOCH: 47], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0117, 	Val Accuracy: 84.03 %
#
# Train Epoch: 48 [0/2812 (0%)]	Train Loss: 0.239865
#
# [EPOCH: 48], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 90.58 %, 	Val Loss: 0.0117, 	Val Accuracy: 82.11 %
#
# Train Epoch: 49 [0/2812 (0%)]	Train Loss: 0.182113
#
# [EPOCH: 49], Lr: {0.003125}	Train Loss: 0.0034, 	Train Accuracy: 90.75 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 50 [0/2812 (0%)]	Train Loss: 0.189064
#
# [EPOCH: 50], Lr: {0.0015625}	Train Loss: 0.0033, 	Train Accuracy: 91.15 %, 	Val Loss: 0.0120, 	Val Accuracy: 82.43 %
#
# Train Epoch: 51 [0/2812 (0%)]	Train Loss: 0.153013
#
# [EPOCH: 51], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 90.93 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.07 %
#
# Train Epoch: 52 [0/2812 (0%)]	Train Loss: 0.198779
#
# [EPOCH: 52], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.07 %
#
# Train Epoch: 53 [0/2812 (0%)]	Train Loss: 0.304162
#
# [EPOCH: 53], Lr: {0.0015625}	Train Loss: 0.0031, 	Train Accuracy: 91.00 %, 	Val Loss: 0.0124, 	Val Accuracy: 82.11 %
#
# Train Epoch: 54 [0/2812 (0%)]	Train Loss: 0.130467
#
# [EPOCH: 54], Lr: {0.0015625}	Train Loss: 0.0030, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.39 %
#
# Train Epoch: 55 [0/2812 (0%)]	Train Loss: 0.138821
#
# [EPOCH: 55], Lr: {0.00078125}	Train Loss: 0.0031, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0118, 	Val Accuracy: 82.75 %
#
# Train Epoch: 56 [0/2812 (0%)]	Train Loss: 0.230033
#
# [EPOCH: 56], Lr: {0.00078125}	Train Loss: 0.0030, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.07 %
#
# Train Epoch: 57 [0/2812 (0%)]	Train Loss: 0.095508
#
# [EPOCH: 57], Lr: {0.00078125}	Train Loss: 0.0030, 	Train Accuracy: 92.00 %, 	Val Loss: 0.0120, 	Val Accuracy: 82.75 %
#
# Train Epoch: 58 [0/2812 (0%)]	Train Loss: 0.146166
#
# [EPOCH: 58], Lr: {0.00078125}	Train Loss: 0.0032, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 59 [0/2812 (0%)]	Train Loss: 0.328589
#
# [EPOCH: 59], Lr: {0.00078125}	Train Loss: 0.0031, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0120, 	Val Accuracy: 82.11 %
#
# Train Epoch: 60 [0/2812 (0%)]	Train Loss: 0.219108
#
# [EPOCH: 60], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0116, 	Val Accuracy: 82.75 %
#
# Train Epoch: 61 [0/2812 (0%)]	Train Loss: 0.158478
#
# [EPOCH: 61], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 91.50 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.71 %
#
# Train Epoch: 62 [0/2812 (0%)]	Train Loss: 0.142824
#
# [EPOCH: 62], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 91.50 %, 	Val Loss: 0.0121, 	Val Accuracy: 82.75 %
#
# Train Epoch: 63 [0/2812 (0%)]	Train Loss: 0.189024
#
# [EPOCH: 63], Lr: {0.000390625}	Train Loss: 0.0031, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 64 [0/2812 (0%)]	Train Loss: 0.255898
#
# [EPOCH: 64], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 90.50 %, 	Val Loss: 0.0118, 	Val Accuracy: 82.43 %
#
# Train Epoch: 65 [0/2812 (0%)]	Train Loss: 0.309027
#
# [EPOCH: 65], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.71 %
#
# Train Epoch: 66 [0/2812 (0%)]	Train Loss: 0.239967
#
# [EPOCH: 66], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 67 [0/2812 (0%)]	Train Loss: 0.238063
#
# [EPOCH: 67], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.39 %
#
# Train Epoch: 68 [0/2812 (0%)]	Train Loss: 0.351846
#
# [EPOCH: 68], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.07 %
#
# Train Epoch: 69 [0/2812 (0%)]	Train Loss: 0.129086
#
# [EPOCH: 69], Lr: {0.0001953125}	Train Loss: 0.0030, 	Train Accuracy: 91.71 %, 	Val Loss: 0.0119, 	Val Accuracy: 82.75 %
#
# Train Epoch: 70 [0/2812 (0%)]	Train Loss: 0.108339
#
# [EPOCH: 70], Lr: {9.765625e-05}	Train Loss: 0.0032, 	Train Accuracy: 90.86 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.39 %
#
# Train Epoch: 71 [0/2812 (0%)]	Train Loss: 0.152968
#
# [EPOCH: 71], Lr: {9.765625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.39 %, 	Val Loss: 0.0119, 	Val Accuracy: 82.75 %
#
# Train Epoch: 72 [0/2812 (0%)]	Train Loss: 0.232032
#
# [EPOCH: 72], Lr: {9.765625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0119, 	Val Accuracy: 82.43 %
#
# Train Epoch: 73 [0/2812 (0%)]	Train Loss: 0.256718
#
# [EPOCH: 73], Lr: {9.765625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.64 %, 	Val Loss: 0.0117, 	Val Accuracy: 82.75 %
#
# Train Epoch: 74 [0/2812 (0%)]	Train Loss: 0.251556
#
# [EPOCH: 74], Lr: {9.765625e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.39 %
#
# Train Epoch: 75 [0/2812 (0%)]	Train Loss: 0.079792
#
# [EPOCH: 75], Lr: {4.8828125e-05}	Train Loss: 0.0032, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0121, 	Val Accuracy: 83.71 %
#
# Train Epoch: 76 [0/2812 (0%)]	Train Loss: 0.188613
#
# [EPOCH: 76], Lr: {4.8828125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.47 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.71 %
#
# Train Epoch: 77 [0/2812 (0%)]	Train Loss: 0.287812
#
# [EPOCH: 77], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.39 %
#
# Train Epoch: 78 [0/2812 (0%)]	Train Loss: 0.268571
#
# [EPOCH: 78], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.39 %
#
# Train Epoch: 79 [0/2812 (0%)]	Train Loss: 0.242230
#
# [EPOCH: 79], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0119, 	Val Accuracy: 82.75 %
#
# Train Epoch: 80 [0/2812 (0%)]	Train Loss: 0.198240
#
# [EPOCH: 80], Lr: {2.44140625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.32 %, 	Val Loss: 0.0117, 	Val Accuracy: 83.39 %
#
# Train Epoch: 81 [0/2812 (0%)]	Train Loss: 0.152553
#
# [EPOCH: 81], Lr: {2.44140625e-05}	Train Loss: 0.0032, 	Train Accuracy: 90.90 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.39 %
#
# Train Epoch: 82 [0/2812 (0%)]	Train Loss: 0.231162
#
# [EPOCH: 82], Lr: {2.44140625e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.25 %, 	Val Loss: 0.0121, 	Val Accuracy: 83.39 %
#
# Train Epoch: 83 [0/2812 (0%)]	Train Loss: 0.203974
#
# [EPOCH: 83], Lr: {2.44140625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.54 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 84 [0/2812 (0%)]	Train Loss: 0.187824
#
# [EPOCH: 84], Lr: {2.44140625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.61 %, 	Val Loss: 0.0122, 	Val Accuracy: 83.39 %
#
# Train Epoch: 85 [0/2812 (0%)]	Train Loss: 0.140749
#
# [EPOCH: 85], Lr: {1.220703125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0117, 	Val Accuracy: 83.71 %
#
# Train Epoch: 86 [0/2812 (0%)]	Train Loss: 0.162841
#
# [EPOCH: 86], Lr: {1.220703125e-05}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.71 %
#
# Train Epoch: 87 [0/2812 (0%)]	Train Loss: 0.149983
#
# [EPOCH: 87], Lr: {1.220703125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.82 %, 	Val Loss: 0.0120, 	Val Accuracy: 82.43 %
#
# Train Epoch: 88 [0/2812 (0%)]	Train Loss: 0.266551
#
# [EPOCH: 88], Lr: {1.220703125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.29 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.71 %
#
# Train Epoch: 89 [0/2812 (0%)]	Train Loss: 0.120829
#
# [EPOCH: 89], Lr: {1.220703125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.39 %
#
# Train Epoch: 90 [0/2812 (0%)]	Train Loss: 0.218510
#
# [EPOCH: 90], Lr: {6.103515625e-06}	Train Loss: 0.0030, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.07 %
#
# Train Epoch: 91 [0/2812 (0%)]	Train Loss: 0.112220
#
# [EPOCH: 91], Lr: {6.103515625e-06}	Train Loss: 0.0030, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.71 %
#
# Train Epoch: 92 [0/2812 (0%)]	Train Loss: 0.110031
#
# [EPOCH: 92], Lr: {6.103515625e-06}	Train Loss: 0.0032, 	Train Accuracy: 90.86 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.07 %
#
# Train Epoch: 93 [0/2812 (0%)]	Train Loss: 0.273023
#
# [EPOCH: 93], Lr: {6.103515625e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.47 %, 	Val Loss: 0.0120, 	Val Accuracy: 83.71 %
#
# Train Epoch: 94 [0/2812 (0%)]	Train Loss: 0.194442
#
# [EPOCH: 94], Lr: {6.103515625e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.47 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.39 %
#
# Train Epoch: 95 [0/2812 (0%)]	Train Loss: 0.228299
#
# [EPOCH: 95], Lr: {3.0517578125e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0119, 	Val Accuracy: 82.75 %
#
# Train Epoch: 96 [0/2812 (0%)]	Train Loss: 0.237095
#
# [EPOCH: 96], Lr: {3.0517578125e-06}	Train Loss: 0.0030, 	Train Accuracy: 91.82 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.71 %
#
# Train Epoch: 97 [0/2812 (0%)]	Train Loss: 0.206190
#
# [EPOCH: 97], Lr: {3.0517578125e-06}	Train Loss: 0.0032, 	Train Accuracy: 90.68 %, 	Val Loss: 0.0120, 	Val Accuracy: 82.75 %
#
# Train Epoch: 98 [0/2812 (0%)]	Train Loss: 0.149995
#
# [EPOCH: 98], Lr: {3.0517578125e-06}	Train Loss: 0.0029, 	Train Accuracy: 91.82 %, 	Val Loss: 0.0118, 	Val Accuracy: 83.39 %
#
# Train Epoch: 99 [0/2812 (0%)]	Train Loss: 0.211453
#
# [EPOCH: 99], Lr: {3.0517578125e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.07 %, 	Val Loss: 0.0119, 	Val Accuracy: 83.71 %
#
# Train Epoch: 100 [0/2812 (0%)]	Train Loss: 0.191129
#
# [EPOCH: 100], Lr: {1.52587890625e-06}	Train Loss: 0.0029, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0117, 	Val Accuracy: 83.07 %
# --------------------Best Model-------------------
# Best Val Epoch:      47
# Best Train Loss:     0.0033
# Best Train Accuracy: 91.0384
# Best Val Loss:       0.0117
# Best Val Accuracy:   84.0256
# ---------------------------------2번째 oof 종료-------------------------------
# ---------------------------------3번째 oof 시작-------------------------------
# Train Epoch: 1 [0/2812 (0%)]	Train Loss: 4.136215
#
# [EPOCH: 1], Lr: {0.1}	Train Loss: 0.0422, 	Train Accuracy: 47.90 %, 	Val Loss: 0.0349, 	Val Accuracy: 51.76 %
#
# Train Epoch: 2 [0/2812 (0%)]	Train Loss: 2.235594
#
# [EPOCH: 2], Lr: {0.1}	Train Loss: 0.0318, 	Train Accuracy: 50.78 %, 	Val Loss: 0.0306, 	Val Accuracy: 52.72 %
#
# Train Epoch: 3 [0/2812 (0%)]	Train Loss: 1.846725
#
# [EPOCH: 3], Lr: {0.1}	Train Loss: 0.0275, 	Train Accuracy: 52.99 %, 	Val Loss: 0.0271, 	Val Accuracy: 55.91 %
#
# Train Epoch: 4 [0/2812 (0%)]	Train Loss: 1.409577
#
# [EPOCH: 4], Lr: {0.1}	Train Loss: 0.0252, 	Train Accuracy: 55.48 %, 	Val Loss: 0.0269, 	Val Accuracy: 55.27 %
#
# Train Epoch: 5 [0/2812 (0%)]	Train Loss: 1.477311
#
# [EPOCH: 5], Lr: {0.1}	Train Loss: 0.0225, 	Train Accuracy: 57.79 %, 	Val Loss: 0.0222, 	Val Accuracy: 62.30 %
#
# Train Epoch: 6 [0/2812 (0%)]	Train Loss: 0.969795
#
# [EPOCH: 6], Lr: {0.1}	Train Loss: 0.0207, 	Train Accuracy: 61.17 %, 	Val Loss: 0.0208, 	Val Accuracy: 63.90 %
#
# Train Epoch: 7 [0/2812 (0%)]	Train Loss: 1.346277
#
# [EPOCH: 7], Lr: {0.1}	Train Loss: 0.0177, 	Train Accuracy: 65.47 %, 	Val Loss: 0.0174, 	Val Accuracy: 67.73 %
#
# Train Epoch: 8 [0/2812 (0%)]	Train Loss: 1.157453
#
# [EPOCH: 8], Lr: {0.1}	Train Loss: 0.0170, 	Train Accuracy: 65.61 %, 	Val Loss: 0.0182, 	Val Accuracy: 64.86 %
#
# Train Epoch: 9 [0/2812 (0%)]	Train Loss: 0.819266
#
# [EPOCH: 9], Lr: {0.1}	Train Loss: 0.0152, 	Train Accuracy: 68.07 %, 	Val Loss: 0.0156, 	Val Accuracy: 70.93 %
#
# Train Epoch: 10 [0/2812 (0%)]	Train Loss: 0.778517
#
# [EPOCH: 10], Lr: {0.1}	Train Loss: 0.0149, 	Train Accuracy: 69.81 %, 	Val Loss: 0.0170, 	Val Accuracy: 71.88 %
#
# Train Epoch: 11 [0/2812 (0%)]	Train Loss: 0.972527
#
# [EPOCH: 11], Lr: {0.1}	Train Loss: 0.0140, 	Train Accuracy: 70.84 %, 	Val Loss: 0.0152, 	Val Accuracy: 72.20 %
#
# Train Epoch: 12 [0/2812 (0%)]	Train Loss: 0.774086
#
# [EPOCH: 12], Lr: {0.1}	Train Loss: 0.0133, 	Train Accuracy: 71.59 %, 	Val Loss: 0.0179, 	Val Accuracy: 72.20 %
#
# Train Epoch: 13 [0/2812 (0%)]	Train Loss: 0.985814
#
# [EPOCH: 13], Lr: {0.1}	Train Loss: 0.0134, 	Train Accuracy: 72.65 %, 	Val Loss: 0.0152, 	Val Accuracy: 73.48 %
#
# Train Epoch: 14 [0/2812 (0%)]	Train Loss: 0.785107
#
# [EPOCH: 14], Lr: {0.1}	Train Loss: 0.0115, 	Train Accuracy: 74.43 %, 	Val Loss: 0.0136, 	Val Accuracy: 77.32 %
#
# Train Epoch: 15 [0/2812 (0%)]	Train Loss: 0.675889
#
# [EPOCH: 15], Lr: {0.1}	Train Loss: 0.0117, 	Train Accuracy: 74.75 %, 	Val Loss: 0.0140, 	Val Accuracy: 74.76 %
#
# Train Epoch: 16 [0/2812 (0%)]	Train Loss: 0.737848
#
# [EPOCH: 16], Lr: {0.1}	Train Loss: 0.0111, 	Train Accuracy: 75.32 %, 	Val Loss: 0.0163, 	Val Accuracy: 72.84 %
#
# Train Epoch: 17 [0/2812 (0%)]	Train Loss: 0.693056
#
# [EPOCH: 17], Lr: {0.1}	Train Loss: 0.0107, 	Train Accuracy: 76.07 %, 	Val Loss: 0.0134, 	Val Accuracy: 76.68 %
#
# Train Epoch: 18 [0/2812 (0%)]	Train Loss: 0.629938
#
# [EPOCH: 18], Lr: {0.1}	Train Loss: 0.0100, 	Train Accuracy: 77.35 %, 	Val Loss: 0.0136, 	Val Accuracy: 78.59 %
#
# Train Epoch: 19 [0/2812 (0%)]	Train Loss: 0.639006
#
# [EPOCH: 19], Lr: {0.1}	Train Loss: 0.0101, 	Train Accuracy: 77.06 %, 	Val Loss: 0.0145, 	Val Accuracy: 75.08 %
#
# Train Epoch: 20 [0/2812 (0%)]	Train Loss: 0.855501
#
# [EPOCH: 20], Lr: {0.1}	Train Loss: 0.0098, 	Train Accuracy: 79.05 %, 	Val Loss: 0.0129, 	Val Accuracy: 77.32 %
#
# Train Epoch: 21 [0/2812 (0%)]	Train Loss: 0.705564
#
# [EPOCH: 21], Lr: {0.1}	Train Loss: 0.0096, 	Train Accuracy: 78.70 %, 	Val Loss: 0.0128, 	Val Accuracy: 77.96 %
#
# Train Epoch: 22 [0/2812 (0%)]	Train Loss: 0.258006
#
# [EPOCH: 22], Lr: {0.1}	Train Loss: 0.0097, 	Train Accuracy: 78.77 %, 	Val Loss: 0.0117, 	Val Accuracy: 79.23 %
#
# Train Epoch: 23 [0/2812 (0%)]	Train Loss: 0.734646
#
# [EPOCH: 23], Lr: {0.1}	Train Loss: 0.0089, 	Train Accuracy: 79.59 %, 	Val Loss: 0.0120, 	Val Accuracy: 80.83 %
#
# Train Epoch: 24 [0/2812 (0%)]	Train Loss: 0.581685
#
# [EPOCH: 24], Lr: {0.1}	Train Loss: 0.0082, 	Train Accuracy: 80.97 %, 	Val Loss: 0.0138, 	Val Accuracy: 76.36 %
#
# Train Epoch: 25 [0/2812 (0%)]	Train Loss: 0.402369
#
# [EPOCH: 25], Lr: {0.1}	Train Loss: 0.0084, 	Train Accuracy: 80.09 %, 	Val Loss: 0.0152, 	Val Accuracy: 74.12 %
#
# Train Epoch: 26 [0/2812 (0%)]	Train Loss: 0.517328
#
# [EPOCH: 26], Lr: {0.1}	Train Loss: 0.0083, 	Train Accuracy: 80.65 %, 	Val Loss: 0.0118, 	Val Accuracy: 78.91 %
#
# Train Epoch: 27 [0/2812 (0%)]	Train Loss: 0.313614
#
# [EPOCH: 27], Lr: {0.1}	Train Loss: 0.0089, 	Train Accuracy: 79.77 %, 	Val Loss: 0.0160, 	Val Accuracy: 72.84 %
#
# Train Epoch: 28 [0/2812 (0%)]	Train Loss: 0.476896
#
# [EPOCH: 28], Lr: {0.05}	Train Loss: 0.0072, 	Train Accuracy: 82.72 %, 	Val Loss: 0.0121, 	Val Accuracy: 79.55 %
#
# Train Epoch: 29 [0/2812 (0%)]	Train Loss: 0.220124
#
# [EPOCH: 29], Lr: {0.05}	Train Loss: 0.0064, 	Train Accuracy: 85.24 %, 	Val Loss: 0.0120, 	Val Accuracy: 81.47 %
#
# Train Epoch: 30 [0/2812 (0%)]	Train Loss: 0.687525
#
# [EPOCH: 30], Lr: {0.05}	Train Loss: 0.0064, 	Train Accuracy: 84.57 %, 	Val Loss: 0.0114, 	Val Accuracy: 81.79 %
#
# Train Epoch: 31 [0/2812 (0%)]	Train Loss: 0.213689
#
# [EPOCH: 31], Lr: {0.05}	Train Loss: 0.0058, 	Train Accuracy: 85.85 %, 	Val Loss: 0.0121, 	Val Accuracy: 79.23 %
#
# Train Epoch: 32 [0/2812 (0%)]	Train Loss: 0.389931
#
# [EPOCH: 32], Lr: {0.05}	Train Loss: 0.0058, 	Train Accuracy: 85.63 %, 	Val Loss: 0.0100, 	Val Accuracy: 81.47 %
#
# Train Epoch: 33 [0/2812 (0%)]	Train Loss: 0.281946
#
# [EPOCH: 33], Lr: {0.05}	Train Loss: 0.0057, 	Train Accuracy: 85.88 %, 	Val Loss: 0.0130, 	Val Accuracy: 77.96 %
#
# Train Epoch: 34 [0/2812 (0%)]	Train Loss: 0.265315
#
# [EPOCH: 34], Lr: {0.05}	Train Loss: 0.0054, 	Train Accuracy: 86.63 %, 	Val Loss: 0.0119, 	Val Accuracy: 80.19 %
#
# Train Epoch: 35 [0/2812 (0%)]	Train Loss: 0.455319
#
# [EPOCH: 35], Lr: {0.05}	Train Loss: 0.0059, 	Train Accuracy: 84.92 %, 	Val Loss: 0.0124, 	Val Accuracy: 79.23 %
#
# Train Epoch: 36 [0/2812 (0%)]	Train Loss: 0.236356
#
# [EPOCH: 36], Lr: {0.05}	Train Loss: 0.0060, 	Train Accuracy: 85.78 %, 	Val Loss: 0.0108, 	Val Accuracy: 81.15 %
#
# Train Epoch: 37 [0/2812 (0%)]	Train Loss: 0.319494
#
# [EPOCH: 37], Lr: {0.05}	Train Loss: 0.0052, 	Train Accuracy: 86.49 %, 	Val Loss: 0.0112, 	Val Accuracy: 80.19 %
#
# Train Epoch: 38 [0/2812 (0%)]	Train Loss: 0.221535
#
# [EPOCH: 38], Lr: {0.025}	Train Loss: 0.0051, 	Train Accuracy: 87.09 %, 	Val Loss: 0.0103, 	Val Accuracy: 82.11 %
#
# Train Epoch: 39 [0/2812 (0%)]	Train Loss: 0.186690
#
# [EPOCH: 39], Lr: {0.025}	Train Loss: 0.0047, 	Train Accuracy: 87.59 %, 	Val Loss: 0.0104, 	Val Accuracy: 81.79 %
#
# Train Epoch: 40 [0/2812 (0%)]	Train Loss: 0.300875
#
# [EPOCH: 40], Lr: {0.025}	Train Loss: 0.0043, 	Train Accuracy: 88.58 %, 	Val Loss: 0.0111, 	Val Accuracy: 82.75 %
#
# Train Epoch: 41 [0/2812 (0%)]	Train Loss: 0.176746
#
# [EPOCH: 41], Lr: {0.025}	Train Loss: 0.0044, 	Train Accuracy: 88.55 %, 	Val Loss: 0.0115, 	Val Accuracy: 80.51 %
#
# Train Epoch: 42 [0/2812 (0%)]	Train Loss: 0.267955
#
# [EPOCH: 42], Lr: {0.025}	Train Loss: 0.0044, 	Train Accuracy: 87.94 %, 	Val Loss: 0.0102, 	Val Accuracy: 82.11 %
#
# Train Epoch: 43 [0/2812 (0%)]	Train Loss: 0.183174
#
# [EPOCH: 43], Lr: {0.0125}	Train Loss: 0.0040, 	Train Accuracy: 89.22 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.75 %
#
# Train Epoch: 44 [0/2812 (0%)]	Train Loss: 0.227308
#
# [EPOCH: 44], Lr: {0.0125}	Train Loss: 0.0038, 	Train Accuracy: 89.79 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.11 %
#
# Train Epoch: 45 [0/2812 (0%)]	Train Loss: 0.374141
#
# [EPOCH: 45], Lr: {0.0125}	Train Loss: 0.0037, 	Train Accuracy: 89.72 %, 	Val Loss: 0.0108, 	Val Accuracy: 82.75 %
#
# Train Epoch: 46 [0/2812 (0%)]	Train Loss: 0.225135
#
# [EPOCH: 46], Lr: {0.0125}	Train Loss: 0.0038, 	Train Accuracy: 89.65 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.39 %
#
# Train Epoch: 47 [0/2812 (0%)]	Train Loss: 0.176505
#
# [EPOCH: 47], Lr: {0.0125}	Train Loss: 0.0040, 	Train Accuracy: 89.19 %, 	Val Loss: 0.0108, 	Val Accuracy: 81.15 %
#
# Train Epoch: 48 [0/2812 (0%)]	Train Loss: 0.494219
#
# [EPOCH: 48], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 90.72 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.11 %
#
# Train Epoch: 49 [0/2812 (0%)]	Train Loss: 0.252258
#
# [EPOCH: 49], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 90.75 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.43 %
#
# Train Epoch: 50 [0/2812 (0%)]	Train Loss: 0.283313
#
# [EPOCH: 50], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 90.43 %, 	Val Loss: 0.0110, 	Val Accuracy: 82.11 %
#
# Train Epoch: 51 [0/2812 (0%)]	Train Loss: 0.194622
#
# [EPOCH: 51], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.79 %, 	Val Loss: 0.0104, 	Val Accuracy: 82.43 %
#
# Train Epoch: 52 [0/2812 (0%)]	Train Loss: 0.267948
#
# [EPOCH: 52], Lr: {0.00625}	Train Loss: 0.0036, 	Train Accuracy: 90.65 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.43 %
#
# Train Epoch: 53 [0/2812 (0%)]	Train Loss: 0.101351
#
# [EPOCH: 53], Lr: {0.003125}	Train Loss: 0.0035, 	Train Accuracy: 90.22 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.11 %
#
# Train Epoch: 54 [0/2812 (0%)]	Train Loss: 0.218740
#
# [EPOCH: 54], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 91.00 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.43 %
#
# Train Epoch: 55 [0/2812 (0%)]	Train Loss: 0.188732
#
# [EPOCH: 55], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 91.00 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.11 %
#
# Train Epoch: 56 [0/2812 (0%)]	Train Loss: 0.190964
#
# [EPOCH: 56], Lr: {0.003125}	Train Loss: 0.0032, 	Train Accuracy: 90.93 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.75 %
#
# Train Epoch: 57 [0/2812 (0%)]	Train Loss: 0.188596
#
# [EPOCH: 57], Lr: {0.003125}	Train Loss: 0.0033, 	Train Accuracy: 90.75 %, 	Val Loss: 0.0108, 	Val Accuracy: 81.79 %
#
# Train Epoch: 58 [0/2812 (0%)]	Train Loss: 0.193685
#
# [EPOCH: 58], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 91.64 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.75 %
#
# Train Epoch: 59 [0/2812 (0%)]	Train Loss: 0.274667
#
# [EPOCH: 59], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.07 %
#
# Train Epoch: 60 [0/2812 (0%)]	Train Loss: 0.142146
#
# [EPOCH: 60], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 90.93 %, 	Val Loss: 0.0108, 	Val Accuracy: 83.39 %
#
# Train Epoch: 61 [0/2812 (0%)]	Train Loss: 0.191551
#
# [EPOCH: 61], Lr: {0.0015625}	Train Loss: 0.0032, 	Train Accuracy: 90.72 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.07 %
#
# Train Epoch: 62 [0/2812 (0%)]	Train Loss: 0.259839
#
# [EPOCH: 62], Lr: {0.0015625}	Train Loss: 0.0034, 	Train Accuracy: 90.47 %, 	Val Loss: 0.0110, 	Val Accuracy: 83.07 %
#
# Train Epoch: 63 [0/2812 (0%)]	Train Loss: 0.083370
#
# [EPOCH: 63], Lr: {0.00078125}	Train Loss: 0.0032, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.75 %
#
# Train Epoch: 64 [0/2812 (0%)]	Train Loss: 0.178548
#
# [EPOCH: 64], Lr: {0.00078125}	Train Loss: 0.0032, 	Train Accuracy: 91.25 %, 	Val Loss: 0.0104, 	Val Accuracy: 83.07 %
#
# Train Epoch: 65 [0/2812 (0%)]	Train Loss: 0.125514
#
# [EPOCH: 65], Lr: {0.00078125}	Train Loss: 0.0032, 	Train Accuracy: 90.90 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.43 %
#
# Train Epoch: 66 [0/2812 (0%)]	Train Loss: 0.149429
#
# [EPOCH: 66], Lr: {0.00078125}	Train Loss: 0.0033, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0108, 	Val Accuracy: 82.11 %
#
# Train Epoch: 67 [0/2812 (0%)]	Train Loss: 0.165481
#
# [EPOCH: 67], Lr: {0.00078125}	Train Loss: 0.0033, 	Train Accuracy: 90.61 %, 	Val Loss: 0.0105, 	Val Accuracy: 83.07 %
#
# Train Epoch: 68 [0/2812 (0%)]	Train Loss: 0.395040
#
# [EPOCH: 68], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 91.79 %, 	Val Loss: 0.0107, 	Val Accuracy: 82.43 %
#
# Train Epoch: 69 [0/2812 (0%)]	Train Loss: 0.372960
#
# [EPOCH: 69], Lr: {0.000390625}	Train Loss: 0.0033, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0105, 	Val Accuracy: 83.07 %
#
# Train Epoch: 70 [0/2812 (0%)]	Train Loss: 0.180300
#
# [EPOCH: 70], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 91.18 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.07 %
#
# Train Epoch: 71 [0/2812 (0%)]	Train Loss: 0.185536
#
# [EPOCH: 71], Lr: {0.000390625}	Train Loss: 0.0032, 	Train Accuracy: 90.75 %, 	Val Loss: 0.0104, 	Val Accuracy: 83.39 %
#
# Train Epoch: 72 [0/2812 (0%)]	Train Loss: 0.136018
#
# [EPOCH: 72], Lr: {0.000390625}	Train Loss: 0.0031, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0106, 	Val Accuracy: 82.43 %
#
# Train Epoch: 73 [0/2812 (0%)]	Train Loss: 0.272921
#
# [EPOCH: 73], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.71 %, 	Val Loss: 0.0105, 	Val Accuracy: 83.07 %
#
# Train Epoch: 74 [0/2812 (0%)]	Train Loss: 0.235981
#
# [EPOCH: 74], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0104, 	Val Accuracy: 83.39 %
#
# Train Epoch: 75 [0/2812 (0%)]	Train Loss: 0.143484
#
# [EPOCH: 75], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0106, 	Val Accuracy: 83.07 %
#
# Train Epoch: 76 [0/2812 (0%)]	Train Loss: 0.274474
#
# [EPOCH: 76], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.36 %, 	Val Loss: 0.0105, 	Val Accuracy: 82.43 %
#
# Train Epoch: 77 [0/2812 (0%)]	Train Loss: 0.259613
#
# [EPOCH: 77], Lr: {0.0001953125}	Train Loss: 0.0032, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0107, 	Val Accuracy: 83.07 %
#
# Train Epoch: 78 [0/2812 (0%)]	Train Loss: 0.116571
#
# ...
#
# Train Epoch: 9 [0/2813 (0%)]	Train Loss: 0.621858
#
# [EPOCH: 9], Lr: {0.1}	Train Loss: 0.0146, 	Train Accuracy: 69.18 %, 	Val Loss: 0.0196, 	Val Accuracy: 68.27 %
#
# Train Epoch: 10 [0/2813 (0%)]	Train Loss: 0.724622
#
# [EPOCH: 10], Lr: {0.1}	Train Loss: 0.0146, 	Train Accuracy: 69.96 %, 	Val Loss: 0.0168, 	Val Accuracy: 72.12 %
#
# Train Epoch: 11 [0/2813 (0%)]	Train Loss: 0.678481
#
# [EPOCH: 11], Lr: {0.1}	Train Loss: 0.0129, 	Train Accuracy: 72.16 %, 	Val Loss: 0.0164, 	Val Accuracy: 70.19 %
#
# Train Epoch: 12 [0/2813 (0%)]	Train Loss: 0.510051
#
# [EPOCH: 12], Lr: {0.1}	Train Loss: 0.0123, 	Train Accuracy: 73.41 %, 	Val Loss: 0.0153, 	Val Accuracy: 75.32 %
#
# Train Epoch: 13 [0/2813 (0%)]	Train Loss: 0.881986
#
# [EPOCH: 13], Lr: {0.1}	Train Loss: 0.0115, 	Train Accuracy: 75.04 %, 	Val Loss: 0.0179, 	Val Accuracy: 66.03 %
#
# Train Epoch: 14 [0/2813 (0%)]	Train Loss: 0.622078
#
# [EPOCH: 14], Lr: {0.1}	Train Loss: 0.0114, 	Train Accuracy: 75.47 %, 	Val Loss: 0.0164, 	Val Accuracy: 72.76 %
#
# Train Epoch: 15 [0/2813 (0%)]	Train Loss: 0.854079
#
# [EPOCH: 15], Lr: {0.1}	Train Loss: 0.0116, 	Train Accuracy: 74.08 %, 	Val Loss: 0.0188, 	Val Accuracy: 73.08 %
#
# Train Epoch: 16 [0/2813 (0%)]	Train Loss: 1.053371
#
# [EPOCH: 16], Lr: {0.1}	Train Loss: 0.0106, 	Train Accuracy: 76.75 %, 	Val Loss: 0.0169, 	Val Accuracy: 72.76 %
#
# Train Epoch: 17 [0/2813 (0%)]	Train Loss: 0.606767
#
# [EPOCH: 17], Lr: {0.1}	Train Loss: 0.0104, 	Train Accuracy: 77.21 %, 	Val Loss: 0.0143, 	Val Accuracy: 77.24 %
#
# Train Epoch: 18 [0/2813 (0%)]	Train Loss: 0.316871
#
# [EPOCH: 18], Lr: {0.1}	Train Loss: 0.0097, 	Train Accuracy: 78.46 %, 	Val Loss: 0.0125, 	Val Accuracy: 76.60 %
#
# Train Epoch: 19 [0/2813 (0%)]	Train Loss: 0.521890
#
# [EPOCH: 19], Lr: {0.1}	Train Loss: 0.0095, 	Train Accuracy: 78.35 %, 	Val Loss: 0.0125, 	Val Accuracy: 78.21 %
#
# Train Epoch: 20 [0/2813 (0%)]	Train Loss: 0.340639
#
# [EPOCH: 20], Lr: {0.1}	Train Loss: 0.0089, 	Train Accuracy: 78.95 %, 	Val Loss: 0.0152, 	Val Accuracy: 74.04 %
#
# Train Epoch: 21 [0/2813 (0%)]	Train Loss: 0.443469
#
# [EPOCH: 21], Lr: {0.1}	Train Loss: 0.0091, 	Train Accuracy: 79.24 %, 	Val Loss: 0.0145, 	Val Accuracy: 70.51 %
#
# Train Epoch: 22 [0/2813 (0%)]	Train Loss: 0.383783
#
# [EPOCH: 22], Lr: {0.1}	Train Loss: 0.0087, 	Train Accuracy: 80.38 %, 	Val Loss: 0.0159, 	Val Accuracy: 72.76 %
#
# Train Epoch: 23 [0/2813 (0%)]	Train Loss: 0.521996
#
# [EPOCH: 23], Lr: {0.1}	Train Loss: 0.0085, 	Train Accuracy: 79.56 %, 	Val Loss: 0.0134, 	Val Accuracy: 79.49 %
#
# Train Epoch: 24 [0/2813 (0%)]	Train Loss: 0.288195
#
# [EPOCH: 24], Lr: {0.1}	Train Loss: 0.0082, 	Train Accuracy: 80.31 %, 	Val Loss: 0.0132, 	Val Accuracy: 75.96 %
#
# Train Epoch: 25 [0/2813 (0%)]	Train Loss: 0.564549
#
# [EPOCH: 25], Lr: {0.05}	Train Loss: 0.0068, 	Train Accuracy: 83.51 %, 	Val Loss: 0.0118, 	Val Accuracy: 79.17 %
#
# Train Epoch: 26 [0/2813 (0%)]	Train Loss: 0.351432
#
# [EPOCH: 26], Lr: {0.05}	Train Loss: 0.0061, 	Train Accuracy: 84.68 %, 	Val Loss: 0.0111, 	Val Accuracy: 78.53 %
#
# Train Epoch: 27 [0/2813 (0%)]	Train Loss: 0.212483
#
# [EPOCH: 27], Lr: {0.05}	Train Loss: 0.0059, 	Train Accuracy: 85.89 %, 	Val Loss: 0.0124, 	Val Accuracy: 79.49 %
#
# Train Epoch: 28 [0/2813 (0%)]	Train Loss: 0.377567
#
# [EPOCH: 28], Lr: {0.05}	Train Loss: 0.0056, 	Train Accuracy: 86.56 %, 	Val Loss: 0.0115, 	Val Accuracy: 81.41 %
#
# Train Epoch: 29 [0/2813 (0%)]	Train Loss: 0.420553
#
# [EPOCH: 29], Lr: {0.05}	Train Loss: 0.0063, 	Train Accuracy: 83.79 %, 	Val Loss: 0.0128, 	Val Accuracy: 78.85 %
#
# Train Epoch: 30 [0/2813 (0%)]	Train Loss: 0.244040
#
# [EPOCH: 30], Lr: {0.05}	Train Loss: 0.0061, 	Train Accuracy: 85.25 %, 	Val Loss: 0.0124, 	Val Accuracy: 80.45 %
#
# Train Epoch: 31 [0/2813 (0%)]	Train Loss: 0.499286
#
# [EPOCH: 31], Lr: {0.05}	Train Loss: 0.0059, 	Train Accuracy: 85.10 %, 	Val Loss: 0.0112, 	Val Accuracy: 80.77 %
#
# Train Epoch: 32 [0/2813 (0%)]	Train Loss: 0.291403
#
# [EPOCH: 32], Lr: {0.025}	Train Loss: 0.0049, 	Train Accuracy: 87.49 %, 	Val Loss: 0.0113, 	Val Accuracy: 82.69 %
#
# Train Epoch: 33 [0/2813 (0%)]	Train Loss: 0.356656
#
# [EPOCH: 33], Lr: {0.025}	Train Loss: 0.0048, 	Train Accuracy: 87.81 %, 	Val Loss: 0.0117, 	Val Accuracy: 81.09 %
#
# Train Epoch: 34 [0/2813 (0%)]	Train Loss: 0.199643
#
# [EPOCH: 34], Lr: {0.025}	Train Loss: 0.0047, 	Train Accuracy: 88.34 %, 	Val Loss: 0.0109, 	Val Accuracy: 82.69 %
#
# Train Epoch: 35 [0/2813 (0%)]	Train Loss: 0.163874
#
# [EPOCH: 35], Lr: {0.025}	Train Loss: 0.0045, 	Train Accuracy: 88.45 %, 	Val Loss: 0.0119, 	Val Accuracy: 78.85 %
#
# Train Epoch: 36 [0/2813 (0%)]	Train Loss: 0.215791
#
# [EPOCH: 36], Lr: {0.025}	Train Loss: 0.0045, 	Train Accuracy: 88.45 %, 	Val Loss: 0.0113, 	Val Accuracy: 80.13 %
#
# Train Epoch: 37 [0/2813 (0%)]	Train Loss: 0.199388
#
# [EPOCH: 37], Lr: {0.025}	Train Loss: 0.0044, 	Train Accuracy: 88.27 %, 	Val Loss: 0.0112, 	Val Accuracy: 80.13 %
#
# Train Epoch: 38 [0/2813 (0%)]	Train Loss: 0.216956
#
# [EPOCH: 38], Lr: {0.025}	Train Loss: 0.0044, 	Train Accuracy: 88.20 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.69 %
#
# Train Epoch: 39 [0/2813 (0%)]	Train Loss: 0.285383
#
# [EPOCH: 39], Lr: {0.025}	Train Loss: 0.0042, 	Train Accuracy: 88.87 %, 	Val Loss: 0.0122, 	Val Accuracy: 80.77 %
#
# Train Epoch: 40 [0/2813 (0%)]	Train Loss: 0.241605
#
# [EPOCH: 40], Lr: {0.0125}	Train Loss: 0.0040, 	Train Accuracy: 89.48 %, 	Val Loss: 0.0109, 	Val Accuracy: 83.65 %
#
# Train Epoch: 41 [0/2813 (0%)]	Train Loss: 0.297505
#
# [EPOCH: 41], Lr: {0.0125}	Train Loss: 0.0038, 	Train Accuracy: 89.80 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 42 [0/2813 (0%)]	Train Loss: 0.224985
#
# [EPOCH: 42], Lr: {0.0125}	Train Loss: 0.0037, 	Train Accuracy: 89.76 %, 	Val Loss: 0.0112, 	Val Accuracy: 82.05 %
#
# Train Epoch: 43 [0/2813 (0%)]	Train Loss: 0.200907
#
# [EPOCH: 43], Lr: {0.0125}	Train Loss: 0.0039, 	Train Accuracy: 89.34 %, 	Val Loss: 0.0112, 	Val Accuracy: 83.65 %
#
# Train Epoch: 44 [0/2813 (0%)]	Train Loss: 0.280237
#
# [EPOCH: 44], Lr: {0.0125}	Train Loss: 0.0036, 	Train Accuracy: 89.48 %, 	Val Loss: 0.0113, 	Val Accuracy: 82.69 %
#
# Train Epoch: 45 [0/2813 (0%)]	Train Loss: 0.232698
#
# [EPOCH: 45], Lr: {0.0125}	Train Loss: 0.0036, 	Train Accuracy: 90.22 %, 	Val Loss: 0.0117, 	Val Accuracy: 82.69 %
#
# Train Epoch: 46 [0/2813 (0%)]	Train Loss: 0.203656
#
# [EPOCH: 46], Lr: {0.00625}	Train Loss: 0.0034, 	Train Accuracy: 90.33 %, 	Val Loss: 0.0112, 	Val Accuracy: 81.73 %
#
# Train Epoch: 47 [0/2813 (0%)]	Train Loss: 0.249382
#
# [EPOCH: 47], Lr: {0.00625}	Train Loss: 0.0033, 	Train Accuracy: 90.76 %, 	Val Loss: 0.0114, 	Val Accuracy: 81.09 %
#
# Train Epoch: 48 [0/2813 (0%)]	Train Loss: 0.144201
#
# [EPOCH: 48], Lr: {0.00625}	Train Loss: 0.0033, 	Train Accuracy: 90.47 %, 	Val Loss: 0.0117, 	Val Accuracy: 81.41 %
#
# Train Epoch: 49 [0/2813 (0%)]	Train Loss: 0.266386
#
# [EPOCH: 49], Lr: {0.00625}	Train Loss: 0.0035, 	Train Accuracy: 90.72 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 50 [0/2813 (0%)]	Train Loss: 0.212923
#
# [EPOCH: 50], Lr: {0.00625}	Train Loss: 0.0033, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0116, 	Val Accuracy: 82.37 %
#
# Train Epoch: 51 [0/2813 (0%)]	Train Loss: 0.212970
#
# [EPOCH: 51], Lr: {0.003125}	Train Loss: 0.0032, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.01 %
#
# Train Epoch: 52 [0/2813 (0%)]	Train Loss: 0.116463
#
# [EPOCH: 52], Lr: {0.003125}	Train Loss: 0.0032, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0113, 	Val Accuracy: 83.01 %
#
# Train Epoch: 53 [0/2813 (0%)]	Train Loss: 0.237941
#
# [EPOCH: 53], Lr: {0.003125}	Train Loss: 0.0031, 	Train Accuracy: 90.79 %, 	Val Loss: 0.0117, 	Val Accuracy: 83.33 %
#
# Train Epoch: 54 [0/2813 (0%)]	Train Loss: 0.273953
#
# [EPOCH: 54], Lr: {0.003125}	Train Loss: 0.0030, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 55 [0/2813 (0%)]	Train Loss: 0.074979
#
# [EPOCH: 55], Lr: {0.003125}	Train Loss: 0.0032, 	Train Accuracy: 91.33 %, 	Val Loss: 0.0115, 	Val Accuracy: 84.29 %
#
# Train Epoch: 56 [0/2813 (0%)]	Train Loss: 0.191059
#
# [EPOCH: 56], Lr: {0.0015625}	Train Loss: 0.0030, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.97 %
#
# Train Epoch: 57 [0/2813 (0%)]	Train Loss: 0.195434
#
# [EPOCH: 57], Lr: {0.0015625}	Train Loss: 0.0030, 	Train Accuracy: 91.25 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 58 [0/2813 (0%)]	Train Loss: 0.170615
#
# [EPOCH: 58], Lr: {0.0015625}	Train Loss: 0.0031, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.37 %
#
# Train Epoch: 59 [0/2813 (0%)]	Train Loss: 0.097442
#
# [EPOCH: 59], Lr: {0.0015625}	Train Loss: 0.0030, 	Train Accuracy: 91.47 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 60 [0/2813 (0%)]	Train Loss: 0.250941
#
# [EPOCH: 60], Lr: {0.0015625}	Train Loss: 0.0030, 	Train Accuracy: 91.79 %, 	Val Loss: 0.0115, 	Val Accuracy: 82.69 %
#
# Train Epoch: 61 [0/2813 (0%)]	Train Loss: 0.247384
#
# [EPOCH: 61], Lr: {0.00078125}	Train Loss: 0.0031, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 62 [0/2813 (0%)]	Train Loss: 0.270842
#
# [EPOCH: 62], Lr: {0.00078125}	Train Loss: 0.0030, 	Train Accuracy: 91.33 %, 	Val Loss: 0.0114, 	Val Accuracy: 82.69 %
#
# Train Epoch: 63 [0/2813 (0%)]	Train Loss: 0.134741
#
# [EPOCH: 63], Lr: {0.00078125}	Train Loss: 0.0029, 	Train Accuracy: 92.07 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.01 %
#
# Train Epoch: 64 [0/2813 (0%)]	Train Loss: 0.093401
#
# [EPOCH: 64], Lr: {0.00078125}	Train Loss: 0.0031, 	Train Accuracy: 91.65 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 65 [0/2813 (0%)]	Train Loss: 0.201880
#
# [EPOCH: 65], Lr: {0.00078125}	Train Loss: 0.0029, 	Train Accuracy: 92.11 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 66 [0/2813 (0%)]	Train Loss: 0.188032
#
# [EPOCH: 66], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 91.43 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 67 [0/2813 (0%)]	Train Loss: 0.309475
#
# [EPOCH: 67], Lr: {0.000390625}	Train Loss: 0.0031, 	Train Accuracy: 90.90 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 68 [0/2813 (0%)]	Train Loss: 0.206421
#
# [EPOCH: 68], Lr: {0.000390625}	Train Loss: 0.0031, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0115, 	Val Accuracy: 84.29 %
#
# Train Epoch: 69 [0/2813 (0%)]	Train Loss: 0.283903
#
# [EPOCH: 69], Lr: {0.000390625}	Train Loss: 0.0030, 	Train Accuracy: 91.61 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.01 %
#
# Train Epoch: 70 [0/2813 (0%)]	Train Loss: 0.110048
#
# [EPOCH: 70], Lr: {0.000390625}	Train Loss: 0.0029, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0117, 	Val Accuracy: 83.65 %
#
# Train Epoch: 71 [0/2813 (0%)]	Train Loss: 0.247236
#
# [EPOCH: 71], Lr: {0.0001953125}	Train Loss: 0.0029, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.01 %
#
# Train Epoch: 72 [0/2813 (0%)]	Train Loss: 0.295612
#
# [EPOCH: 72], Lr: {0.0001953125}	Train Loss: 0.0029, 	Train Accuracy: 91.86 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.65 %
#
# Train Epoch: 73 [0/2813 (0%)]	Train Loss: 0.133515
#
# [EPOCH: 73], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.57 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.65 %
#
# Train Epoch: 74 [0/2813 (0%)]	Train Loss: 0.288627
#
# [EPOCH: 74], Lr: {0.0001953125}	Train Loss: 0.0031, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 75 [0/2813 (0%)]	Train Loss: 0.165768
#
# [EPOCH: 75], Lr: {0.0001953125}	Train Loss: 0.0029, 	Train Accuracy: 91.79 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.97 %
#
# Train Epoch: 76 [0/2813 (0%)]	Train Loss: 0.085651
#
# [EPOCH: 76], Lr: {9.765625e-05}	Train Loss: 0.0029, 	Train Accuracy: 91.04 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.65 %
#
# Train Epoch: 77 [0/2813 (0%)]	Train Loss: 0.410789
#
# [EPOCH: 77], Lr: {9.765625e-05}	Train Loss: 0.0030, 	Train Accuracy: 92.14 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 78 [0/2813 (0%)]	Train Loss: 0.229856
#
# [EPOCH: 78], Lr: {9.765625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.72 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 79 [0/2813 (0%)]	Train Loss: 0.085541
#
# [EPOCH: 79], Lr: {9.765625e-05}	Train Loss: 0.0029, 	Train Accuracy: 91.11 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.65 %
#
# Train Epoch: 80 [0/2813 (0%)]	Train Loss: 0.097971
#
# [EPOCH: 80], Lr: {9.765625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.40 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 81 [0/2813 (0%)]	Train Loss: 0.371262
#
# [EPOCH: 81], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.08 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 82 [0/2813 (0%)]	Train Loss: 0.185162
#
# [EPOCH: 82], Lr: {4.8828125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.72 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.65 %
#
# Train Epoch: 83 [0/2813 (0%)]	Train Loss: 0.170272
#
# [EPOCH: 83], Lr: {4.8828125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.29 %, 	Val Loss: 0.0115, 	Val Accuracy: 82.69 %
#
# Train Epoch: 84 [0/2813 (0%)]	Train Loss: 0.295492
#
# [EPOCH: 84], Lr: {4.8828125e-05}	Train Loss: 0.0030, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.65 %
#
# Train Epoch: 85 [0/2813 (0%)]	Train Loss: 0.193448
#
# [EPOCH: 85], Lr: {4.8828125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.72 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.65 %
#
# Train Epoch: 86 [0/2813 (0%)]	Train Loss: 0.189992
#
# [EPOCH: 86], Lr: {2.44140625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.61 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.01 %
#
# Train Epoch: 87 [0/2813 (0%)]	Train Loss: 0.176557
#
# [EPOCH: 87], Lr: {2.44140625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.15 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 88 [0/2813 (0%)]	Train Loss: 0.275039
#
# [EPOCH: 88], Lr: {2.44140625e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.54 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 89 [0/2813 (0%)]	Train Loss: 0.121136
#
# [EPOCH: 89], Lr: {2.44140625e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.33 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 90 [0/2813 (0%)]	Train Loss: 0.286084
#
# [EPOCH: 90], Lr: {2.44140625e-05}	Train Loss: 0.0029, 	Train Accuracy: 91.82 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.65 %
#
# Train Epoch: 91 [0/2813 (0%)]	Train Loss: 0.327337
#
# [EPOCH: 91], Lr: {1.220703125e-05}	Train Loss: 0.0029, 	Train Accuracy: 91.68 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.33 %
#
# Train Epoch: 92 [0/2813 (0%)]	Train Loss: 0.261695
#
# [EPOCH: 92], Lr: {1.220703125e-05}	Train Loss: 0.0028, 	Train Accuracy: 92.04 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.97 %
#
# Train Epoch: 93 [0/2813 (0%)]	Train Loss: 0.136611
#
# [EPOCH: 93], Lr: {1.220703125e-05}	Train Loss: 0.0030, 	Train Accuracy: 91.22 %, 	Val Loss: 0.0116, 	Val Accuracy: 83.01 %
#
# Train Epoch: 94 [0/2813 (0%)]	Train Loss: 0.149450
#
# [EPOCH: 94], Lr: {1.220703125e-05}	Train Loss: 0.0031, 	Train Accuracy: 90.97 %, 	Val Loss: 0.0114, 	Val Accuracy: 84.29 %
#
# Train Epoch: 95 [0/2813 (0%)]	Train Loss: 0.421022
#
# [EPOCH: 95], Lr: {1.220703125e-05}	Train Loss: 0.0031, 	Train Accuracy: 91.50 %, 	Val Loss: 0.0114, 	Val Accuracy: 83.01 %
#
# Train Epoch: 96 [0/2813 (0%)]	Train Loss: 0.132878
#
# [EPOCH: 96], Lr: {6.103515625e-06}	Train Loss: 0.0029, 	Train Accuracy: 91.50 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 97 [0/2813 (0%)]	Train Loss: 0.205234
#
# [EPOCH: 97], Lr: {6.103515625e-06}	Train Loss: 0.0031, 	Train Accuracy: 91.15 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.65 %
#
# Train Epoch: 98 [0/2813 (0%)]	Train Loss: 0.202988
#
# [EPOCH: 98], Lr: {6.103515625e-06}	Train Loss: 0.0029, 	Train Accuracy: 92.04 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 99 [0/2813 (0%)]	Train Loss: 0.250110
#
# [EPOCH: 99], Lr: {6.103515625e-06}	Train Loss: 0.0030, 	Train Accuracy: 91.25 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.33 %
#
# Train Epoch: 100 [0/2813 (0%)]	Train Loss: 0.130304
#
# [EPOCH: 100], Lr: {6.103515625e-06}	Train Loss: 0.0030, 	Train Accuracy: 91.47 %, 	Val Loss: 0.0115, 	Val Accuracy: 83.97 %
# --------------------Best Model-------------------
# Best Val Epoch:      94
# Best Train Loss:     0.0031
# Best Train Accuracy: 90.9705
# Best Val Loss:       0.0114
# Best Val Accuracy:   84.2949
# ---------------------------------10번째 oof 종료-------------------------------

# %%
from sklearn.metrics import accuracy_score

print('Train accuracy_score: ', accuracy_score(train_oof, y))
# Out:
# Train accuracy_score:  0.83584

# %%
submission.iloc[:,1:] = test_oof
submission.to_csv('CNN_kford_10.csv',index=False)
submission.head()
# Out:
#      id             0             1  ...            58            59            60
# 0  3125  1.063167e-07  8.997465e-05  ...  4.611881e-03  1.705465e-07  2.331555e-06
# 1  3126  1.035539e-04  5.176955e-08  ...  7.170677e-12  1.040409e-06  2.554091e-07
# 2  3127  3.417896e-03  1.211369e-02  ...  4.681747e-08  5.575053e-03  4.844488e-02
# 3  3128  1.006441e-04  6.082305e-09  ...  4.575505e-10  3.627715e-09  1.975328e-02
# 4  3129  7.476994e-03  5.003398e-07  ...  7.021610e-08  3.664094e-11  6.382011e-04
#
# [5 rows x 62 columns]
